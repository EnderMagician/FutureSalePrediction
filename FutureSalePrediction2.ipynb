# %% [markdown]
# # Kaggle "Predict Future Sales" Competition
# ### 1. Problem Definition:
# - Goal: Predict total sales for every product and store in the following month.

# %% [markdown]
# ### 2. Data Exploration:

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 100)

from itertools import product
from sklearn.preprocessing import LabelEncoder

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from xgboost import XGBRegressor
from xgboost import plot_importance
from IPython.display import Markdown

def plot_features(booster, figsize):    
    fig, ax = plt.subplots(1,1,figsize=figsize)
    return plot_importance(booster=booster, ax=ax)

import time
import sys
import gc
import pickle
sys.version_info
# Out:
# sys.version_info(major=3, minor=13, micro=2, releaselevel='final', serial=0)

# %%
#Read Data Sets
path = 'Dataset/'

DataDescription = Markdown(f"[Dataset Description]({path}DatasetDescription)")
display("This is Dataset Description, provided by Kaggle")
display(DataDescription)

cats  = pd.read_csv(path + 'item_categories.csv')
items          = pd.read_csv(path + 'items.csv')
train       = pd.read_csv(path + 'sales_train.csv')
train['date'] = pd.to_datetime(train['date'], format="%d.%m.%Y")
sub_df = pd.read_csv(path + 'sample_submission.csv')
shops         = pd.read_csv(path + 'shops.csv')
test = pd.read_csv(path + 'test.csv')
# Out:
# 'This is Dataset Description, provided by Kaggle'
# [Dataset Description](Dataset/DatasetDescription)

# %% [markdown]
# Let's first have a look at the data sets:

# %% [markdown]
# We will examine salesTrain Dataset.

# %%
plt.figure(figsize=(10,4))
plt.xlim(-100, 3000)
sns.boxplot(x=train.item_cnt_day)

plt.figure(figsize=(10,4))
plt.xlim(train.item_price.min(), train.item_price.max()*1.1)
sns.boxplot(x=train.item_price)
# Out:
# <Axes: xlabel='item_price'>

# %%
train = train[train.item_price<100000]
train = train[train.item_cnt_day<1001]

# %% [markdown]
# Starting with date_block_num column to see if there are any possible missing values.

# %%
median = train[(train.shop_id==32)&(train.item_id==2973)&(train.date_block_num==4)&(train.item_price>0)].item_price.median()
train.loc[train.item_price<0, 'item_price'] = median

# %%
# Якутск Орджоникидзе, 56
train.loc[train.shop_id == 0, 'shop_id'] = 57
test.loc[test.shop_id == 0, 'shop_id'] = 57
# Якутск ТЦ "Центральный"
train.loc[train.shop_id == 1, 'shop_id'] = 58
test.loc[test.shop_id == 1, 'shop_id'] = 58
# Жуковский ул. Чкалова 39м²
train.loc[train.shop_id == 10, 'shop_id'] = 11
test.loc[test.shop_id == 10, 'shop_id'] = 11

# %%
shops.loc[shops.shop_name == 'Сергиев Посад ТЦ "7Я"', 'shop_name'] = 'СергиевПосад ТЦ "7Я"'
shops['city'] = shops['shop_name'].str.split(' ').map(lambda x: x[0])
shops.loc[shops.city == '!Якутск', 'city'] = 'Якутск'
shops['city_code'] = LabelEncoder().fit_transform(shops['city'])
shops = shops[['shop_id','city_code']]

cats['split'] = cats['item_category_name'].str.split('-')
cats['type'] = cats['split'].map(lambda x: x[0].strip())
cats['type_code'] = LabelEncoder().fit_transform(cats['type'])
# if subtype is nan then type
cats['subtype'] = cats['split'].map(lambda x: x[1].strip() if len(x) > 1 else x[0].strip())
cats['subtype_code'] = LabelEncoder().fit_transform(cats['subtype'])
cats = cats[['item_category_id','type_code', 'subtype_code']]

items.drop(['item_name'], axis=1, inplace=True)

# %% [markdown]
# # Cleaning shops datas

# %%
len(list(set(test.item_id) - set(test.item_id).intersection(set(train.item_id)))), len(list(set(test.item_id))), len(test)
# Out:
# (363, 5100, 214200)

# %%
matrix = []
cols = ['date_block_num','shop_id','item_id']
for i in range(34):
    sales = train[train.date_block_num==i]
    matrix.append(np.array(list(product([i], sales.shop_id.unique(), sales.item_id.unique())), dtype='int16'))
    
matrix = pd.DataFrame(np.vstack(matrix), columns=cols)
matrix['date_block_num'] = matrix['date_block_num'].astype(np.int8)
matrix['shop_id'] = matrix['shop_id'].astype(np.int8)
matrix['item_id'] = matrix['item_id'].astype(np.int16)
matrix.sort_values(cols,inplace=True)

# %%
train['revenue'] = train['item_price'] *  train['item_cnt_day']

# %%
group = train.groupby(['date_block_num','shop_id','item_id']).agg({'item_cnt_day': ['sum']})
group.columns = ['item_cnt_month']
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=cols, how='left')
matrix['item_cnt_month'] = (matrix['item_cnt_month']
                                .fillna(0)
                                .clip(0,20) # NB clip target here
                                .astype(np.float16))

# %%
test['date_block_num'] = 34
test['date_block_num'] = test['date_block_num'].astype(np.int8)
test['shop_id'] = test['shop_id'].astype(np.int8)
test['item_id'] = test['item_id'].astype(np.int16)

# %%
matrix = pd.concat([matrix, test], ignore_index=True, sort=False, keys=cols)
matrix.fillna(0, inplace=True) # 34 month
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_33824\1469943207.py:1: FutureWarning: The behavior of pd.concat with len(keys) != len(objs) is deprecated. In a future version this will raise instead of truncating to the smaller of the two sequences
#   matrix = pd.concat([matrix, test], ignore_index=True, sort=False, keys=cols)

# %% [markdown]
# # cleaning item datas

# %%
matrix = pd.merge(matrix, shops, on=['shop_id'], how='left')
matrix = pd.merge(matrix, items, on=['item_id'], how='left')
matrix = pd.merge(matrix, cats, on=['item_category_id'], how='left')
matrix['city_code'] = matrix['city_code'].astype(np.int8)
matrix['item_category_id'] = matrix['item_category_id'].astype(np.int8)
matrix['type_code'] = matrix['type_code'].astype(np.int8)
matrix['subtype_code'] = matrix['subtype_code'].astype(np.int8)

# %%
def lag_feature(df, lags, col):
    tmp = df[['date_block_num','shop_id','item_id',col]]
    for i in lags:
        shifted = tmp.copy()
        shifted.columns = ['date_block_num','shop_id','item_id', col+'_lag_'+str(i)]
        shifted['date_block_num'] += i
        df = pd.merge(df, shifted, on=['date_block_num','shop_id','item_id'], how='left')
    return df

# %%
matrix = lag_feature(matrix, [1,2,3,6,12], 'item_cnt_month')

# %%
group = matrix.groupby(['date_block_num']).agg({'item_cnt_month': ['mean']})
group.columns = [ 'date_avg_item_cnt' ]
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num'], how='left')
matrix['date_avg_item_cnt'] = matrix['date_avg_item_cnt'].astype(np.float16)
matrix = lag_feature(matrix, [1], 'date_avg_item_cnt')
matrix.drop(['date_avg_item_cnt'], axis=1, inplace=True)

# %%
group = matrix.groupby(['date_block_num', 'item_id']).agg({'item_cnt_month': ['mean']})
group.columns = [ 'date_item_avg_item_cnt' ]
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num','item_id'], how='left')
matrix['date_item_avg_item_cnt'] = matrix['date_item_avg_item_cnt'].astype(np.float16)
matrix = lag_feature(matrix, [1,2,3,6,12], 'date_item_avg_item_cnt')
matrix.drop(['date_item_avg_item_cnt'], axis=1, inplace=True)

# %%
group = matrix.groupby(['date_block_num', 'shop_id']).agg({'item_cnt_month': ['mean']})
group.columns = [ 'date_shop_avg_item_cnt' ]
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num','shop_id'], how='left')
matrix['date_shop_avg_item_cnt'] = matrix['date_shop_avg_item_cnt'].astype(np.float16)
matrix = lag_feature(matrix, [1,2,3,6,12], 'date_shop_avg_item_cnt')
matrix.drop(['date_shop_avg_item_cnt'], axis=1, inplace=True)

# %%
group = matrix.groupby(['date_block_num', 'item_category_id']).agg({'item_cnt_month': ['mean']})
group.columns = [ 'date_cat_avg_item_cnt' ]
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num','item_category_id'], how='left')
matrix['date_cat_avg_item_cnt'] = matrix['date_cat_avg_item_cnt'].astype(np.float16)
matrix = lag_feature(matrix, [1], 'date_cat_avg_item_cnt')
matrix.drop(['date_cat_avg_item_cnt'], axis=1, inplace=True)

# %%
group = matrix.groupby(['date_block_num', 'shop_id', 'item_category_id']).agg({'item_cnt_month': ['mean']})
group.columns = ['date_shop_cat_avg_item_cnt']
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num', 'shop_id', 'item_category_id'], how='left')
matrix['date_shop_cat_avg_item_cnt'] = matrix['date_shop_cat_avg_item_cnt'].astype(np.float16)
matrix = lag_feature(matrix, [1], 'date_shop_cat_avg_item_cnt')
matrix.drop(['date_shop_cat_avg_item_cnt'], axis=1, inplace=True)

# %%
group = matrix.groupby(['date_block_num', 'shop_id', 'type_code']).agg({'item_cnt_month': ['mean']})
group.columns = ['date_shop_type_avg_item_cnt']
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num', 'shop_id', 'type_code'], how='left')
matrix['date_shop_type_avg_item_cnt'] = matrix['date_shop_type_avg_item_cnt'].astype(np.float16)
matrix = lag_feature(matrix, [1], 'date_shop_type_avg_item_cnt')
matrix.drop(['date_shop_type_avg_item_cnt'], axis=1, inplace=True)

# %%
group = matrix.groupby(['date_block_num', 'shop_id', 'subtype_code']).agg({'item_cnt_month': ['mean']})
group.columns = ['date_shop_subtype_avg_item_cnt']
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num', 'shop_id', 'subtype_code'], how='left')
matrix['date_shop_subtype_avg_item_cnt'] = matrix['date_shop_subtype_avg_item_cnt'].astype(np.float16)
matrix = lag_feature(matrix, [1], 'date_shop_subtype_avg_item_cnt')
matrix.drop(['date_shop_subtype_avg_item_cnt'], axis=1, inplace=True)

# %%
group = matrix.groupby(['date_block_num', 'city_code']).agg({'item_cnt_month': ['mean']})
group.columns = [ 'date_city_avg_item_cnt' ]
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num', 'city_code'], how='left')
matrix['date_city_avg_item_cnt'] = matrix['date_city_avg_item_cnt'].astype(np.float16)
matrix = lag_feature(matrix, [1], 'date_city_avg_item_cnt')
matrix.drop(['date_city_avg_item_cnt'], axis=1, inplace=True)

# %%
group = matrix.groupby(['date_block_num', 'item_id', 'city_code']).agg({'item_cnt_month': ['mean']})
group.columns = [ 'date_item_city_avg_item_cnt' ]
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num', 'item_id', 'city_code'], how='left')
matrix['date_item_city_avg_item_cnt'] = matrix['date_item_city_avg_item_cnt'].astype(np.float16)
matrix = lag_feature(matrix, [1], 'date_item_city_avg_item_cnt')
matrix.drop(['date_item_city_avg_item_cnt'], axis=1, inplace=True)

# %% [markdown]
# # Cleaning item cat datas

# %%
group = matrix.groupby(['date_block_num', 'type_code']).agg({'item_cnt_month': ['mean']})
group.columns = [ 'date_type_avg_item_cnt' ]
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num', 'type_code'], how='left')
matrix['date_type_avg_item_cnt'] = matrix['date_type_avg_item_cnt'].astype(np.float16)
matrix = lag_feature(matrix, [1], 'date_type_avg_item_cnt')
matrix.drop(['date_type_avg_item_cnt'], axis=1, inplace=True)

# %%
group = matrix.groupby(['date_block_num', 'subtype_code']).agg({'item_cnt_month': ['mean']})
group.columns = [ 'date_subtype_avg_item_cnt' ]
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num', 'subtype_code'], how='left')
matrix['date_subtype_avg_item_cnt'] = matrix['date_subtype_avg_item_cnt'].astype(np.float16)
matrix = lag_feature(matrix, [1], 'date_subtype_avg_item_cnt')
matrix.drop(['date_subtype_avg_item_cnt'], axis=1, inplace=True)

# %%
group = train.groupby(['item_id']).agg({'item_price': ['mean']})
group.columns = ['item_avg_item_price']
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['item_id'], how='left')
matrix['item_avg_item_price'] = matrix['item_avg_item_price'].astype(np.float16)

group = train.groupby(['date_block_num','item_id']).agg({'item_price': ['mean']})
group.columns = ['date_item_avg_item_price']
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num','item_id'], how='left')
matrix['date_item_avg_item_price'] = matrix['date_item_avg_item_price'].astype(np.float16)

lags = [1,2,3,4,5,6]
matrix = lag_feature(matrix, lags, 'date_item_avg_item_price')

for i in lags:
    matrix['delta_price_lag_'+str(i)] = \
        (matrix['date_item_avg_item_price_lag_'+str(i)] - matrix['item_avg_item_price']) / matrix['item_avg_item_price']

def select_trend(row):
    for i in lags:
        if row['delta_price_lag_'+str(i)]:
            return row['delta_price_lag_'+str(i)]
    return 0
    
matrix['delta_price_lag'] = matrix.apply(select_trend, axis=1)
matrix['delta_price_lag'] = matrix['delta_price_lag'].astype(np.float16)
matrix['delta_price_lag'].fillna(0, inplace=True)



fetures_to_drop = ['item_avg_item_price', 'date_item_avg_item_price']
for i in lags:
    fetures_to_drop += ['date_item_avg_item_price_lag_'+str(i)]
    fetures_to_drop += ['delta_price_lag_'+str(i)]

matrix.drop(fetures_to_drop, axis=1, inplace=True)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_33824\2079020359.py:30: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   matrix['delta_price_lag'].fillna(0, inplace=True)

# %%
group = train.groupby(['date_block_num','shop_id']).agg({'revenue': ['sum']})
group.columns = ['date_shop_revenue']
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num','shop_id'], how='left')
matrix['date_shop_revenue'] = matrix['date_shop_revenue'].astype(np.float32)

group = group.groupby(['shop_id']).agg({'date_shop_revenue': ['mean']})
group.columns = ['shop_avg_revenue']
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['shop_id'], how='left')
matrix['shop_avg_revenue'] = matrix['shop_avg_revenue'].astype(np.float32)

matrix['delta_revenue'] = (matrix['date_shop_revenue'] - matrix['shop_avg_revenue']) / matrix['shop_avg_revenue']
matrix['delta_revenue'] = matrix['delta_revenue'].astype(np.float16)

matrix = lag_feature(matrix, [1], 'delta_revenue')

matrix.drop(['date_shop_revenue','shop_avg_revenue','delta_revenue'], axis=1, inplace=True)

# %%
matrix['month'] = matrix['date_block_num'] % 12

# %% [markdown]
# # Data pre-processing and feature engineering

# %%
days = pd.Series([31,28,31,30,31,30,31,31,30,31,30,31])
matrix['days'] = matrix['month'].map(days).astype(np.int8)

# %%
cache = {}
matrix['item_shop_last_sale'] = -1
matrix['item_shop_last_sale'] = matrix['item_shop_last_sale'].astype(np.int8)
for idx, row in matrix.iterrows():    
    key = str(row.item_id)+' '+str(row.shop_id)
    if key not in cache:
        if row.item_cnt_month!=0:
            cache[key] = row.date_block_num
    else:
        last_date_block_num = cache[key]
        matrix.at[idx, 'item_shop_last_sale'] = row.date_block_num - last_date_block_num
        cache[key] = row.date_block_num

# %%
cache = {}
matrix['item_last_sale'] = -1
matrix['item_last_sale'] = matrix['item_last_sale'].astype(np.int8)
for idx, row in matrix.iterrows():    
    key = row.item_id
    if key not in cache:
        if row.item_cnt_month!=0:
            cache[key] = row.date_block_num
    else:
        last_date_block_num = cache[key]
        if row.date_block_num>last_date_block_num:
            matrix.at[idx, 'item_last_sale'] = row.date_block_num - last_date_block_num
            cache[key] = row.date_block_num

# %%
matrix['item_shop_first_sale'] = matrix['date_block_num'] - matrix.groupby(['item_id','shop_id'])['date_block_num'].transform('min')
matrix['item_first_sale'] = matrix['date_block_num'] - matrix.groupby('item_id')['date_block_num'].transform('min')

# %%
matrix = matrix[matrix.date_block_num > 11]

# %%
def fill_na(df):
    for col in df.columns:
        if ('_lag_' in col) & (df[col].isnull().any()):
            if ('item_cnt' in col):
                df[col].fillna(0, inplace=True)         
    return df

matrix = fill_na(matrix)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_33824\4139583225.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(0, inplace=True)

# %%
matrix.columns
# Out:
# Index(['date_block_num', 'shop_id', 'item_id', 'item_cnt_month', 'ID',
#        'city_code', 'item_category_id', 'type_code', 'subtype_code',
#        'item_cnt_month_lag_1', 'item_cnt_month_lag_2', 'item_cnt_month_lag_3',
#        'item_cnt_month_lag_6', 'item_cnt_month_lag_12',
#        'date_avg_item_cnt_lag_1', 'date_item_avg_item_cnt_lag_1',
#        'date_item_avg_item_cnt_lag_2', 'date_item_avg_item_cnt_lag_3',
#        'date_item_avg_item_cnt_lag_6', 'date_item_avg_item_cnt_lag_12',
#        'date_shop_avg_item_cnt_lag_1', 'date_shop_avg_item_cnt_lag_2',
#        'date_shop_avg_item_cnt_lag_3', 'date_shop_avg_item_cnt_lag_6',
#        'date_shop_avg_item_cnt_lag_12', 'date_cat_avg_item_cnt_lag_1',
#        'date_shop_cat_avg_item_cnt_lag_1', 'date_shop_type_avg_item_cnt_lag_1',
#        'date_shop_subtype_avg_item_cnt_lag_1', 'date_city_avg_item_cnt_lag_1',
#        'date_item_city_avg_item_cnt_lag_1', 'date_type_avg_item_cnt_lag_1',
#        'date_subtype_avg_item_cnt_lag_1', 'delta_price_lag',
#        'delta_revenue_lag_1', 'month', 'days', 'item_shop_last_sale',
#        'item_last_sale', 'item_shop_first_sale', 'item_first_sale'],
#       dtype='object')

# %%
# # Tính tổng item_cnt_month theo date_block_num
# total_item_cnt_month_by_block = concat_df.groupby('date_block_num')['item_cnt_month'].sum().reset_index()

# # Vẽ biểu đồ barplot
# sns.barplot(x='date_block_num', y='item_cnt_month', data=total_item_cnt_month_by_block)
# plt.title('Total item_cnt_month by date_block_num')
# plt.xlabel('date_block_num')
# plt.ylabel('Total item_cnt_month')
# plt.xticks(rotation=90)  # Xoay nhãn trục x cho dễ đọc nếu cần
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 2
#       1 # Tính tổng item_cnt_month theo date_block_num
# ----> 2 total_item_cnt_month_by_block = concat_df.groupby('date_block_num')['item_cnt_month'].sum().reset_index()
#       4 # Vẽ biểu đồ barplot
#       5 sns.barplot(x='date_block_num', y='item_cnt_month', data=total_item_cnt_month_by_block)
#
# NameError: name 'concat_df' is not defined

# %%
matrix.to_pickle('data.pkl')
del matrix
del cache
del group
del items
del shops
del cats
del train
# leave test for submission
gc.collect();

# %% [markdown]
# ### 4. Model Selection:

# %%
data = pd.read_pickle('data.pkl')

# %%
data = data[[
    'date_block_num',
    'shop_id',
    'item_id',
    'item_cnt_month',
    'city_code',
    'item_category_id',
    'type_code',
    'subtype_code',
    'item_cnt_month_lag_1',
    'item_cnt_month_lag_2',
    'item_cnt_month_lag_3',
    'item_cnt_month_lag_6',
    'item_cnt_month_lag_12',
    'date_avg_item_cnt_lag_1',
    'date_item_avg_item_cnt_lag_1',
    'date_item_avg_item_cnt_lag_2',
    'date_item_avg_item_cnt_lag_3',
    'date_item_avg_item_cnt_lag_6',
    'date_item_avg_item_cnt_lag_12',
    'date_shop_avg_item_cnt_lag_1',
    'date_shop_avg_item_cnt_lag_2',
    'date_shop_avg_item_cnt_lag_3',
    'date_shop_avg_item_cnt_lag_6',
    'date_shop_avg_item_cnt_lag_12',
    'date_cat_avg_item_cnt_lag_1',
    'date_shop_cat_avg_item_cnt_lag_1',
    #'date_shop_type_avg_item_cnt_lag_1',
    #'date_shop_subtype_avg_item_cnt_lag_1',
    'date_city_avg_item_cnt_lag_1',
    'date_item_city_avg_item_cnt_lag_1',
    #'date_type_avg_item_cnt_lag_1',
    #'date_subtype_avg_item_cnt_lag_1',
    'delta_price_lag',
    'month',
    'days',
    'item_shop_last_sale',
    'item_last_sale',
    'item_shop_first_sale',
    'item_first_sale',
]]

# %%
X_train = data[data.date_block_num < 33].drop(['item_cnt_month'], axis=1)
Y_train = data[data.date_block_num < 33]['item_cnt_month']
X_valid = data[data.date_block_num == 33].drop(['item_cnt_month'], axis=1)
Y_valid = data[data.date_block_num == 33]['item_cnt_month']
X_test = data[data.date_block_num == 34].drop(['item_cnt_month'], axis=1)

# %%
del data
gc.collect();

# %%
import xgboost as xgb

# Cấu hình tham số trong xgb_param
xgb_param = {
    'max_depth': 8,
    'n_estimators': 1000,
    'min_child_weight': 300,
    'colsample_bytree': 0.8,
    'subsample': 0.8,
    'learning_rate': 0.3,  # 'eta' được thay bằng 'learning_rate'
    'seed': 42,
    'eval_metric': 'rmse'
}

# Khởi tạo mô hình XGBRegressor với các tham số từ xgb_param
model = xgb.XGBRegressor(**xgb_param)

# Huấn luyện mô hình với eval_set mà không có EarlyStopping
model.fit(
    X_train,
    Y_train,
    eval_set=[(X_train, Y_train), (X_valid, Y_valid)],
    verbose=True
)
# Out:
# [0]	validation_0-rmse:1.04046	validation_1-rmse:1.02594
# [1]	validation_0-rmse:0.95506	validation_1-rmse:0.96955
# [2]	validation_0-rmse:0.90901	validation_1-rmse:0.94591
# [3]	validation_0-rmse:0.88261	validation_1-rmse:0.93263
# [4]	validation_0-rmse:0.86477	validation_1-rmse:0.92237
# [5]	validation_0-rmse:0.85370	validation_1-rmse:0.91923
# [6]	validation_0-rmse:0.84388	validation_1-rmse:0.91417
# [7]	validation_0-rmse:0.83793	validation_1-rmse:0.91406
# [8]	validation_0-rmse:0.83384	validation_1-rmse:0.91345
# [9]	validation_0-rmse:0.83016	validation_1-rmse:0.91253
# [10]	validation_0-rmse:0.82786	validation_1-rmse:0.91152
# [11]	validation_0-rmse:0.82391	validation_1-rmse:0.91300
# [12]	validation_0-rmse:0.82205	validation_1-rmse:0.91280
# [13]	validation_0-rmse:0.82043	validation_1-rmse:0.91296
# [14]	validation_0-rmse:0.81773	validation_1-rmse:0.91374
# [15]	validation_0-rmse:0.81678	validation_1-rmse:0.91325
# [16]	validation_0-rmse:0.81496	validation_1-rmse:0.91318
# [17]	validation_0-rmse:0.81413	validation_1-rmse:0.91276
# [18]	validation_0-rmse:0.81230	validation_1-rmse:0.91489
# [19]	validation_0-rmse:0.81155	validation_1-rmse:0.91450
# [20]	validation_0-rmse:0.81071	validation_1-rmse:0.91534
# [21]	validation_0-rmse:0.80980	validation_1-rmse:0.91495
# [22]	validation_0-rmse:0.80904	validation_1-rmse:0.91471
# [23]	validation_0-rmse:0.80773	validation_1-rmse:0.91373
# [24]	validation_0-rmse:0.80712	validation_1-rmse:0.91424
# [25]	validation_0-rmse:0.80645	validation_1-rmse:0.91433
# [26]	validation_0-rmse:0.80542	validation_1-rmse:0.91427
# [27]	validation_0-rmse:0.80382	validation_1-rmse:0.91386
# [28]	validation_0-rmse:0.80317	validation_1-rmse:0.91665
# [29]	validation_0-rmse:0.80260	validation_1-rmse:0.91730
# [30]	validation_0-rmse:0.80201	validation_1-rmse:0.91715
# [31]	validation_0-rmse:0.80121	validation_1-rmse:0.91714
# [32]	validation_0-rmse:0.80077	validation_1-rmse:0.91655
# [33]	validation_0-rmse:0.80005	validation_1-rmse:0.91760
# [34]	validation_0-rmse:0.79957	validation_1-rmse:0.91701
# [35]	validation_0-rmse:0.79925	validation_1-rmse:0.91663
# [36]	validation_0-rmse:0.79725	validation_1-rmse:0.91214
# [37]	validation_0-rmse:0.79667	validation_1-rmse:0.91243
# [38]	validation_0-rmse:0.79616	validation_1-rmse:0.91290
# [39]	validation_0-rmse:0.79565	validation_1-rmse:0.91237
# [40]	validation_0-rmse:0.79519	validation_1-rmse:0.91250
# [41]	validation_0-rmse:0.79477	validation_1-rmse:0.91243
# [42]	validation_0-rmse:0.79380	validation_1-rmse:0.91288
# [43]	validation_0-rmse:0.79331	validation_1-rmse:0.91253
# [44]	validation_0-rmse:0.79270	validation_1-rmse:0.91329
# [45]	validation_0-rmse:0.79197	validation_1-rmse:0.91459
# [46]	validation_0-rmse:0.79137	validation_1-rmse:0.91448
# [47]	validation_0-rmse:0.79095	validation_1-rmse:0.91432
# [48]	validation_0-rmse:0.79045	validation_1-rmse:0.91462
# [49]	validation_0-rmse:0.78999	validation_1-rmse:0.91438
# [50]	validation_0-rmse:0.78966	validation_1-rmse:0.91425
# [51]	validation_0-rmse:0.78625	validation_1-rmse:0.91531
# [52]	validation_0-rmse:0.78540	validation_1-rmse:0.91567
# [53]	validation_0-rmse:0.78514	validation_1-rmse:0.91569
# [54]	validation_0-rmse:0.78489	validation_1-rmse:0.91576
# [55]	validation_0-rmse:0.78450	validation_1-rmse:0.91594
# [56]	validation_0-rmse:0.78430	validation_1-rmse:0.91630
# [57]	validation_0-rmse:0.78412	validation_1-rmse:0.91615
# [58]	validation_0-rmse:0.78355	validation_1-rmse:0.91588
# [59]	validation_0-rmse:0.78327	validation_1-rmse:0.91608
# [60]	validation_0-rmse:0.78160	validation_1-rmse:0.91505
# [61]	validation_0-rmse:0.78077	validation_1-rmse:0.91524
# [62]	validation_0-rmse:0.77906	validation_1-rmse:0.91648
# [63]	validation_0-rmse:0.77888	validation_1-rmse:0.91648
# [64]	validation_0-rmse:0.77851	validation_1-rmse:0.91657
# [65]	validation_0-rmse:0.77793	validation_1-rmse:0.91627
# [66]	validation_0-rmse:0.77764	validation_1-rmse:0.91633
# [67]	validation_0-rmse:0.77740	validation_1-rmse:0.91620
# [68]	validation_0-rmse:0.77706	validation_1-rmse:0.91571
# [69]	validation_0-rmse:0.77674	validation_1-rmse:0.91577
# [70]	validation_0-rmse:0.77600	validation_1-rmse:0.91596
# [71]	validation_0-rmse:0.77580	validation_1-rmse:0.91606
# [72]	validation_0-rmse:0.77548	validation_1-rmse:0.91611
# [73]	validation_0-rmse:0.77522	validation_1-rmse:0.91609
# [74]	validation_0-rmse:0.77470	validation_1-rmse:0.91561
# [75]	validation_0-rmse:0.77352	validation_1-rmse:0.91552
# [76]	validation_0-rmse:0.77315	validation_1-rmse:0.91528
# [77]	validation_0-rmse:0.77300	validation_1-rmse:0.91565
# [78]	validation_0-rmse:0.77252	validation_1-rmse:0.91511
# [79]	validation_0-rmse:0.77201	validation_1-rmse:0.91558
# [80]	validation_0-rmse:0.77152	validation_1-rmse:0.91555
# [81]	validation_0-rmse:0.77134	validation_1-rmse:0.91557
# [82]	validation_0-rmse:0.77102	validation_1-rmse:0.91610
# [83]	validation_0-rmse:0.77089	validation_1-rmse:0.91583
# [84]	validation_0-rmse:0.77069	validation_1-rmse:0.91546
# [85]	validation_0-rmse:0.77043	validation_1-rmse:0.91549
# [86]	validation_0-rmse:0.76912	validation_1-rmse:0.91598
# [87]	validation_0-rmse:0.76887	validation_1-rmse:0.91628
# [88]	validation_0-rmse:0.76833	validation_1-rmse:0.91613
# [89]	validation_0-rmse:0.76808	validation_1-rmse:0.91615
# [90]	validation_0-rmse:0.76761	validation_1-rmse:0.91596
# [91]	validation_0-rmse:0.76741	validation_1-rmse:0.91695
# [92]	validation_0-rmse:0.76721	validation_1-rmse:0.91714
# [93]	validation_0-rmse:0.76698	validation_1-rmse:0.91723
# [94]	validation_0-rmse:0.76615	validation_1-rmse:0.91794
# [95]	validation_0-rmse:0.76595	validation_1-rmse:0.91743
# [96]	validation_0-rmse:0.76581	validation_1-rmse:0.91761
# [97]	validation_0-rmse:0.76566	validation_1-rmse:0.91759
# [98]	validation_0-rmse:0.76531	validation_1-rmse:0.91813
# [99]	validation_0-rmse:0.76484	validation_1-rmse:0.91827
# [100]	validation_0-rmse:0.76440	validation_1-rmse:0.91863
# [101]	validation_0-rmse:0.76421	validation_1-rmse:0.91883
# [102]	validation_0-rmse:0.76408	validation_1-rmse:0.91859
# [103]	validation_0-rmse:0.76384	validation_1-rmse:0.91914
# [104]	validation_0-rmse:0.76367	validation_1-rmse:0.91913
# [105]	validation_0-rmse:0.76355	validation_1-rmse:0.91924
# [106]	validation_0-rmse:0.76324	validation_1-rmse:0.91808
# [107]	validation_0-rmse:0.76316	validation_1-rmse:0.91825
# [108]	validation_0-rmse:0.76296	validation_1-rmse:0.91855
# [109]	validation_0-rmse:0.76219	validation_1-rmse:0.91851
# [110]	validation_0-rmse:0.76205	validation_1-rmse:0.91851
# [111]	validation_0-rmse:0.76189	validation_1-rmse:0.91856
# [112]	validation_0-rmse:0.76165	validation_1-rmse:0.91830
# [113]	validation_0-rmse:0.76142	validation_1-rmse:0.91830
# [114]	validation_0-rmse:0.76003	validation_1-rmse:0.91874
# [115]	validation_0-rmse:0.75962	validation_1-rmse:0.91895
# [116]	validation_0-rmse:0.75942	validation_1-rmse:0.91873
# [117]	validation_0-rmse:0.75924	validation_1-rmse:0.91885
# [118]	validation_0-rmse:0.75832	validation_1-rmse:0.91947
# [119]	validation_0-rmse:0.75806	validation_1-rmse:0.91972
# [120]	validation_0-rmse:0.75777	validation_1-rmse:0.92030
# [121]	validation_0-rmse:0.75755	validation_1-rmse:0.92029
# [122]	validation_0-rmse:0.75744	validation_1-rmse:0.92056
# [123]	validation_0-rmse:0.75728	validation_1-rmse:0.91999
# [124]	validation_0-rmse:0.75666	validation_1-rmse:0.92022
# [125]	validation_0-rmse:0.75654	validation_1-rmse:0.92017
# [126]	validation_0-rmse:0.75604	validation_1-rmse:0.92046
# [127]	validation_0-rmse:0.75580	validation_1-rmse:0.92005
# [128]	validation_0-rmse:0.75562	validation_1-rmse:0.91985
# [129]	validation_0-rmse:0.75547	validation_1-rmse:0.92019
# [130]	validation_0-rmse:0.75537	validation_1-rmse:0.92004
# [131]	validation_0-rmse:0.75513	validation_1-rmse:0.92041
# [132]	validation_0-rmse:0.75489	validation_1-rmse:0.92043
# [133]	validation_0-rmse:0.75478	validation_1-rmse:0.92038
# [134]	validation_0-rmse:0.75435	validation_1-rmse:0.92058
# [135]	validation_0-rmse:0.75424	validation_1-rmse:0.92057
# [136]	validation_0-rmse:0.75410	validation_1-rmse:0.92039
# [137]	validation_0-rmse:0.75395	validation_1-rmse:0.92004
# [138]	validation_0-rmse:0.75383	validation_1-rmse:0.92049
# [139]	validation_0-rmse:0.75347	validation_1-rmse:0.92075
# [140]	validation_0-rmse:0.75315	validation_1-rmse:0.92277
# [141]	validation_0-rmse:0.75210	validation_1-rmse:0.92460
# [142]	validation_0-rmse:0.75202	validation_1-rmse:0.92468
# [143]	validation_0-rmse:0.75174	validation_1-rmse:0.92466
# [144]	validation_0-rmse:0.75132	validation_1-rmse:0.92450
# [145]	validation_0-rmse:0.75110	validation_1-rmse:0.92404
# [146]	validation_0-rmse:0.75098	validation_1-rmse:0.92395
# [147]	validation_0-rmse:0.75075	validation_1-rmse:0.92399
# [148]	validation_0-rmse:0.75063	validation_1-rmse:0.92388
# [149]	validation_0-rmse:0.75048	validation_1-rmse:0.92371
# [150]	validation_0-rmse:0.75038	validation_1-rmse:0.92355
# [151]	validation_0-rmse:0.75021	validation_1-rmse:0.92351
# [152]	validation_0-rmse:0.75006	validation_1-rmse:0.92376
# [153]	validation_0-rmse:0.74994	validation_1-rmse:0.92353
# [154]	validation_0-rmse:0.74986	validation_1-rmse:0.92359
# [155]	validation_0-rmse:0.74967	validation_1-rmse:0.92354
# [156]	validation_0-rmse:0.74959	validation_1-rmse:0.92345
# [157]	validation_0-rmse:0.74940	validation_1-rmse:0.92311
# [158]	validation_0-rmse:0.74919	validation_1-rmse:0.92319
# [159]	validation_0-rmse:0.74908	validation_1-rmse:0.92328
# [160]	validation_0-rmse:0.74883	validation_1-rmse:0.92330
# [161]	validation_0-rmse:0.74870	validation_1-rmse:0.92323
# [162]	validation_0-rmse:0.74852	validation_1-rmse:0.92298
# [163]	validation_0-rmse:0.74837	validation_1-rmse:0.92302
# [164]	validation_0-rmse:0.74823	validation_1-rmse:0.92300
# [165]	validation_0-rmse:0.74813	validation_1-rmse:0.92301
# [166]	validation_0-rmse:0.74803	validation_1-rmse:0.92378
# [167]	validation_0-rmse:0.74793	validation_1-rmse:0.92405
# [168]	validation_0-rmse:0.74775	validation_1-rmse:0.92425
# [169]	validation_0-rmse:0.74767	validation_1-rmse:0.92421
# [170]	validation_0-rmse:0.74743	validation_1-rmse:0.92433
# [171]	validation_0-rmse:0.74720	validation_1-rmse:0.92465
# [172]	validation_0-rmse:0.74702	validation_1-rmse:0.92433
# [173]	validation_0-rmse:0.74661	validation_1-rmse:0.92417
# [174]	validation_0-rmse:0.74641	validation_1-rmse:0.92423
# [175]	validation_0-rmse:0.74630	validation_1-rmse:0.92479
# [176]	validation_0-rmse:0.74613	validation_1-rmse:0.92478
# [177]	validation_0-rmse:0.74602	validation_1-rmse:0.92481
# [178]	validation_0-rmse:0.74585	validation_1-rmse:0.92468
# [179]	validation_0-rmse:0.74493	validation_1-rmse:0.92620
# [180]	validation_0-rmse:0.74482	validation_1-rmse:0.92617
# [181]	validation_0-rmse:0.74451	validation_1-rmse:0.92638
# [182]	validation_0-rmse:0.74445	validation_1-rmse:0.92615
# [183]	validation_0-rmse:0.74431	validation_1-rmse:0.92607
# [184]	validation_0-rmse:0.74420	validation_1-rmse:0.92643
# [185]	validation_0-rmse:0.74412	validation_1-rmse:0.92695
# [186]	validation_0-rmse:0.74405	validation_1-rmse:0.92697
# [187]	validation_0-rmse:0.74398	validation_1-rmse:0.92705
# [188]	validation_0-rmse:0.74383	validation_1-rmse:0.92710
# [189]	validation_0-rmse:0.74373	validation_1-rmse:0.92704
# [190]	validation_0-rmse:0.74360	validation_1-rmse:0.92687
# [191]	validation_0-rmse:0.74272	validation_1-rmse:0.92877
# [192]	validation_0-rmse:0.74258	validation_1-rmse:0.92858
# [193]	validation_0-rmse:0.74232	validation_1-rmse:0.92876
# [194]	validation_0-rmse:0.74220	validation_1-rmse:0.92884
# [195]	validation_0-rmse:0.74214	validation_1-rmse:0.92898
# [196]	validation_0-rmse:0.74201	validation_1-rmse:0.92936
# [197]	validation_0-rmse:0.74191	validation_1-rmse:0.92929
# [198]	validation_0-rmse:0.74183	validation_1-rmse:0.92928
# [199]	validation_0-rmse:0.74169	validation_1-rmse:0.92919
# [200]	validation_0-rmse:0.74162	validation_1-rmse:0.92918
# [201]	validation_0-rmse:0.74149	validation_1-rmse:0.92931
# [202]	validation_0-rmse:0.74136	validation_1-rmse:0.92943
# [203]	validation_0-rmse:0.74124	validation_1-rmse:0.92958
# [204]	validation_0-rmse:0.74115	validation_1-rmse:0.92924
# [205]	validation_0-rmse:0.74101	validation_1-rmse:0.92935
# [206]	validation_0-rmse:0.74087	validation_1-rmse:0.92935
# [207]	validation_0-rmse:0.74075	validation_1-rmse:0.92932
# [208]	validation_0-rmse:0.74066	validation_1-rmse:0.92929
# [209]	validation_0-rmse:0.74058	validation_1-rmse:0.92928
# [210]	validation_0-rmse:0.74047	validation_1-rmse:0.92919
# [211]	validation_0-rmse:0.74036	validation_1-rmse:0.92899
# [212]	validation_0-rmse:0.74029	validation_1-rmse:0.92877
# [213]	validation_0-rmse:0.74014	validation_1-rmse:0.92877
# [214]	validation_0-rmse:0.73992	validation_1-rmse:0.92895
# [215]	validation_0-rmse:0.73981	validation_1-rmse:0.92904
# [216]	validation_0-rmse:0.73971	validation_1-rmse:0.92911
# [217]	validation_0-rmse:0.73959	validation_1-rmse:0.92922
# [218]	validation_0-rmse:0.73951	validation_1-rmse:0.92921
# [219]	validation_0-rmse:0.73939	validation_1-rmse:0.92908
# [220]	validation_0-rmse:0.73926	validation_1-rmse:0.92917
# [221]	validation_0-rmse:0.73918	validation_1-rmse:0.92914
# [222]	validation_0-rmse:0.73910	validation_1-rmse:0.92922
# [223]	validation_0-rmse:0.73898	validation_1-rmse:0.92912
# [224]	validation_0-rmse:0.73887	validation_1-rmse:0.92919
# [225]	validation_0-rmse:0.73878	validation_1-rmse:0.92919
# [226]	validation_0-rmse:0.73868	validation_1-rmse:0.92958
# [227]	validation_0-rmse:0.73851	validation_1-rmse:0.92956
# [228]	validation_0-rmse:0.73840	validation_1-rmse:0.92951
# [229]	validation_0-rmse:0.73834	validation_1-rmse:0.92974
# [230]	validation_0-rmse:0.73825	validation_1-rmse:0.92985
# [231]	validation_0-rmse:0.73816	validation_1-rmse:0.92978
# [232]	validation_0-rmse:0.73799	validation_1-rmse:0.92993
# [233]	validation_0-rmse:0.73791	validation_1-rmse:0.92989
# [234]	validation_0-rmse:0.73781	validation_1-rmse:0.93005
# [235]	validation_0-rmse:0.73769	validation_1-rmse:0.93032
# [236]	validation_0-rmse:0.73750	validation_1-rmse:0.93080
# [237]	validation_0-rmse:0.73742	validation_1-rmse:0.93082
# [238]	validation_0-rmse:0.73722	validation_1-rmse:0.93046
# [239]	validation_0-rmse:0.73714	validation_1-rmse:0.93064
# [240]	validation_0-rmse:0.73704	validation_1-rmse:0.93052
# [241]	validation_0-rmse:0.73692	validation_1-rmse:0.93038
# [242]	validation_0-rmse:0.73644	validation_1-rmse:0.92882
# [243]	validation_0-rmse:0.73635	validation_1-rmse:0.92890
# [244]	validation_0-rmse:0.73628	validation_1-rmse:0.92898
# [245]	validation_0-rmse:0.73615	validation_1-rmse:0.92905
# [246]	validation_0-rmse:0.73606	validation_1-rmse:0.92913
# [247]	validation_0-rmse:0.73598	validation_1-rmse:0.92945
# [248]	validation_0-rmse:0.73591	validation_1-rmse:0.92952
# [249]	validation_0-rmse:0.73579	validation_1-rmse:0.92984
# [250]	validation_0-rmse:0.73561	validation_1-rmse:0.92986
# [251]	validation_0-rmse:0.73526	validation_1-rmse:0.93004
# [252]	validation_0-rmse:0.73513	validation_1-rmse:0.92999
# [253]	validation_0-rmse:0.73509	validation_1-rmse:0.92999
# [254]	validation_0-rmse:0.73501	validation_1-rmse:0.92993
# [255]	validation_0-rmse:0.73471	validation_1-rmse:0.92905
# [256]	validation_0-rmse:0.73455	validation_1-rmse:0.92887
# [257]	validation_0-rmse:0.73447	validation_1-rmse:0.92820
# [258]	validation_0-rmse:0.73440	validation_1-rmse:0.92864
# [259]	validation_0-rmse:0.73432	validation_1-rmse:0.92879
# [260]	validation_0-rmse:0.73413	validation_1-rmse:0.92879
# [261]	validation_0-rmse:0.73399	validation_1-rmse:0.92882
# [262]	validation_0-rmse:0.73378	validation_1-rmse:0.93014
# [263]	validation_0-rmse:0.73366	validation_1-rmse:0.93002
# [264]	validation_0-rmse:0.73359	validation_1-rmse:0.92991
# [265]	validation_0-rmse:0.73352	validation_1-rmse:0.93029
# [266]	validation_0-rmse:0.73339	validation_1-rmse:0.93042
# [267]	validation_0-rmse:0.73322	validation_1-rmse:0.93077
# [268]	validation_0-rmse:0.73315	validation_1-rmse:0.93055
# [269]	validation_0-rmse:0.73304	validation_1-rmse:0.93047
# [270]	validation_0-rmse:0.73296	validation_1-rmse:0.93053
# [271]	validation_0-rmse:0.73256	validation_1-rmse:0.93056
# [272]	validation_0-rmse:0.73249	validation_1-rmse:0.93117
# [273]	validation_0-rmse:0.73107	validation_1-rmse:0.93209
# [274]	validation_0-rmse:0.73100	validation_1-rmse:0.93213
# [275]	validation_0-rmse:0.73083	validation_1-rmse:0.93226
# [276]	validation_0-rmse:0.73071	validation_1-rmse:0.93202
# [277]	validation_0-rmse:0.73066	validation_1-rmse:0.93208
# [278]	validation_0-rmse:0.73052	validation_1-rmse:0.93248
# [279]	validation_0-rmse:0.73037	validation_1-rmse:0.93261
# [280]	validation_0-rmse:0.73029	validation_1-rmse:0.93224
# [281]	validation_0-rmse:0.73017	validation_1-rmse:0.93212
# [282]	validation_0-rmse:0.73004	validation_1-rmse:0.93241
# [283]	validation_0-rmse:0.72985	validation_1-rmse:0.93183
# [284]	validation_0-rmse:0.72967	validation_1-rmse:0.93155
# [285]	validation_0-rmse:0.72961	validation_1-rmse:0.93185
# [286]	validation_0-rmse:0.72953	validation_1-rmse:0.93204
# [287]	validation_0-rmse:0.72945	validation_1-rmse:0.93217
# [288]	validation_0-rmse:0.72789	validation_1-rmse:0.93709
# [289]	validation_0-rmse:0.72782	validation_1-rmse:0.93740
# [290]	validation_0-rmse:0.72762	validation_1-rmse:0.93831
# [291]	validation_0-rmse:0.72705	validation_1-rmse:0.93901
# [292]	validation_0-rmse:0.72696	validation_1-rmse:0.93885
# [293]	validation_0-rmse:0.72693	validation_1-rmse:0.93886
# [294]	validation_0-rmse:0.72687	validation_1-rmse:0.93906
# [295]	validation_0-rmse:0.72674	validation_1-rmse:0.93909
# [296]	validation_0-rmse:0.72667	validation_1-rmse:0.93888
# [297]	validation_0-rmse:0.72657	validation_1-rmse:0.93891
# [298]	validation_0-rmse:0.72559	validation_1-rmse:0.94268
# [299]	validation_0-rmse:0.72551	validation_1-rmse:0.94252
# [300]	validation_0-rmse:0.72544	validation_1-rmse:0.94264
# [301]	validation_0-rmse:0.72537	validation_1-rmse:0.94245
# [302]	validation_0-rmse:0.72533	validation_1-rmse:0.94252
# [303]	validation_0-rmse:0.72519	validation_1-rmse:0.94276
# [304]	validation_0-rmse:0.72514	validation_1-rmse:0.94264
# [305]	validation_0-rmse:0.72507	validation_1-rmse:0.94240
# [306]	validation_0-rmse:0.72502	validation_1-rmse:0.94274
# [307]	validation_0-rmse:0.72495	validation_1-rmse:0.94282
# [308]	validation_0-rmse:0.72489	validation_1-rmse:0.94287
# [309]	validation_0-rmse:0.72480	validation_1-rmse:0.94278
# [310]	validation_0-rmse:0.72471	validation_1-rmse:0.94253
# [311]	validation_0-rmse:0.72465	validation_1-rmse:0.94272
# [312]	validation_0-rmse:0.72450	validation_1-rmse:0.94278
# [313]	validation_0-rmse:0.72442	validation_1-rmse:0.94284
# [314]	validation_0-rmse:0.72430	validation_1-rmse:0.94294
# [315]	validation_0-rmse:0.72424	validation_1-rmse:0.94308
# [316]	validation_0-rmse:0.72418	validation_1-rmse:0.94326
# [317]	validation_0-rmse:0.72411	validation_1-rmse:0.94371
# [318]	validation_0-rmse:0.72403	validation_1-rmse:0.94383
# [319]	validation_0-rmse:0.72397	validation_1-rmse:0.94373
# [320]	validation_0-rmse:0.72391	validation_1-rmse:0.94439
# [321]	validation_0-rmse:0.72382	validation_1-rmse:0.94426
# [322]	validation_0-rmse:0.72294	validation_1-rmse:0.94488
# [323]	validation_0-rmse:0.72279	validation_1-rmse:0.94480
# [324]	validation_0-rmse:0.72195	validation_1-rmse:0.94510
# [325]	validation_0-rmse:0.72186	validation_1-rmse:0.94511
# [326]	validation_0-rmse:0.72179	validation_1-rmse:0.94481
# [327]	validation_0-rmse:0.72172	validation_1-rmse:0.94488
# [328]	validation_0-rmse:0.72164	validation_1-rmse:0.94464
# [329]	validation_0-rmse:0.72152	validation_1-rmse:0.94469
# [330]	validation_0-rmse:0.72143	validation_1-rmse:0.94480
# [331]	validation_0-rmse:0.72129	validation_1-rmse:0.94485
# [332]	validation_0-rmse:0.72126	validation_1-rmse:0.94478
# [333]	validation_0-rmse:0.72118	validation_1-rmse:0.94489
# [334]	validation_0-rmse:0.72112	validation_1-rmse:0.94485
# [335]	validation_0-rmse:0.72103	validation_1-rmse:0.94509
# [336]	validation_0-rmse:0.72095	validation_1-rmse:0.94498
# [337]	validation_0-rmse:0.72087	validation_1-rmse:0.94516
# [338]	validation_0-rmse:0.72083	validation_1-rmse:0.94500
# [339]	validation_0-rmse:0.72075	validation_1-rmse:0.94499
# [340]	validation_0-rmse:0.72067	validation_1-rmse:0.94497
# [341]	validation_0-rmse:0.72056	validation_1-rmse:0.94508
# [342]	validation_0-rmse:0.72033	validation_1-rmse:0.94519
# [343]	validation_0-rmse:0.72020	validation_1-rmse:0.94532
# [344]	validation_0-rmse:0.72011	validation_1-rmse:0.94511
# [345]	validation_0-rmse:0.72002	validation_1-rmse:0.94504
# [346]	validation_0-rmse:0.71994	validation_1-rmse:0.94505
# [347]	validation_0-rmse:0.71973	validation_1-rmse:0.94533
# [348]	validation_0-rmse:0.71961	validation_1-rmse:0.94561
# [349]	validation_0-rmse:0.71956	validation_1-rmse:0.94549
# [350]	validation_0-rmse:0.71900	validation_1-rmse:0.94970
# [351]	validation_0-rmse:0.71895	validation_1-rmse:0.94967
# [352]	validation_0-rmse:0.71889	validation_1-rmse:0.94961
# [353]	validation_0-rmse:0.71880	validation_1-rmse:0.94955
# [354]	validation_0-rmse:0.71873	validation_1-rmse:0.94956
# [355]	validation_0-rmse:0.71863	validation_1-rmse:0.94954
# [356]	validation_0-rmse:0.71846	validation_1-rmse:0.95002
# [357]	validation_0-rmse:0.71840	validation_1-rmse:0.94990
# [358]	validation_0-rmse:0.71829	validation_1-rmse:0.94981
# [359]	validation_0-rmse:0.71825	validation_1-rmse:0.94994
# [360]	validation_0-rmse:0.71817	validation_1-rmse:0.94984
# [361]	validation_0-rmse:0.71811	validation_1-rmse:0.94987
# [362]	validation_0-rmse:0.71806	validation_1-rmse:0.94991
# [363]	validation_0-rmse:0.71793	validation_1-rmse:0.94986
# [364]	validation_0-rmse:0.71789	validation_1-rmse:0.94976
# [365]	validation_0-rmse:0.71776	validation_1-rmse:0.95024
# [366]	validation_0-rmse:0.71769	validation_1-rmse:0.95046
# [367]	validation_0-rmse:0.71765	validation_1-rmse:0.95043
# [368]	validation_0-rmse:0.71757	validation_1-rmse:0.95033
# [369]	validation_0-rmse:0.71753	validation_1-rmse:0.95020
# [370]	validation_0-rmse:0.71741	validation_1-rmse:0.95025
# [371]	validation_0-rmse:0.71735	validation_1-rmse:0.95016
# [372]	validation_0-rmse:0.71729	validation_1-rmse:0.94986
# [373]	validation_0-rmse:0.71721	validation_1-rmse:0.94952
# [374]	validation_0-rmse:0.71714	validation_1-rmse:0.94958
# [375]	validation_0-rmse:0.71707	validation_1-rmse:0.94984
# [376]	validation_0-rmse:0.71699	validation_1-rmse:0.94965
# [377]	validation_0-rmse:0.71689	validation_1-rmse:0.94926
# [378]	validation_0-rmse:0.71682	validation_1-rmse:0.94938
# [379]	validation_0-rmse:0.71674	validation_1-rmse:0.94934
# [380]	validation_0-rmse:0.71659	validation_1-rmse:0.94932
# [381]	validation_0-rmse:0.71655	validation_1-rmse:0.94907
# [382]	validation_0-rmse:0.71640	validation_1-rmse:0.94923
# [383]	validation_0-rmse:0.71634	validation_1-rmse:0.94916
# [384]	validation_0-rmse:0.71625	validation_1-rmse:0.94922
# [385]	validation_0-rmse:0.71615	validation_1-rmse:0.94918
# [386]	validation_0-rmse:0.71605	validation_1-rmse:0.94930
# [387]	validation_0-rmse:0.71588	validation_1-rmse:0.94921
# [388]	validation_0-rmse:0.71580	validation_1-rmse:0.94901
# [389]	validation_0-rmse:0.71571	validation_1-rmse:0.94883
# [390]	validation_0-rmse:0.71565	validation_1-rmse:0.94869
# [391]	validation_0-rmse:0.71550	validation_1-rmse:0.94846
# [392]	validation_0-rmse:0.71537	validation_1-rmse:0.94853
# [393]	validation_0-rmse:0.71533	validation_1-rmse:0.94842
# [394]	validation_0-rmse:0.71520	validation_1-rmse:0.94856
# [395]	validation_0-rmse:0.71510	validation_1-rmse:0.94872
# [396]	validation_0-rmse:0.71506	validation_1-rmse:0.94880
# [397]	validation_0-rmse:0.71497	validation_1-rmse:0.94885
# [398]	validation_0-rmse:0.71482	validation_1-rmse:0.94906
# [399]	validation_0-rmse:0.71476	validation_1-rmse:0.94885
# [400]	validation_0-rmse:0.71472	validation_1-rmse:0.94879
# [401]	validation_0-rmse:0.71466	validation_1-rmse:0.94864
# [402]	validation_0-rmse:0.71462	validation_1-rmse:0.94850
# [403]	validation_0-rmse:0.71453	validation_1-rmse:0.94836
# [404]	validation_0-rmse:0.71436	validation_1-rmse:0.94837
# [405]	validation_0-rmse:0.71431	validation_1-rmse:0.94837
# [406]	validation_0-rmse:0.71427	validation_1-rmse:0.94821
# [407]	validation_0-rmse:0.71414	validation_1-rmse:0.94821
# [408]	validation_0-rmse:0.71408	validation_1-rmse:0.94830
# [409]	validation_0-rmse:0.71401	validation_1-rmse:0.94834
# [410]	validation_0-rmse:0.71393	validation_1-rmse:0.94830
# [411]	validation_0-rmse:0.71385	validation_1-rmse:0.94809
# [412]	validation_0-rmse:0.71368	validation_1-rmse:0.94807
# [413]	validation_0-rmse:0.71361	validation_1-rmse:0.94800
# [414]	validation_0-rmse:0.71354	validation_1-rmse:0.94835
# [415]	validation_0-rmse:0.71350	validation_1-rmse:0.94849
# [416]	validation_0-rmse:0.71345	validation_1-rmse:0.94840
# [417]	validation_0-rmse:0.71336	validation_1-rmse:0.94869
# [418]	validation_0-rmse:0.71329	validation_1-rmse:0.94845
# [419]	validation_0-rmse:0.71308	validation_1-rmse:0.94859
# [420]	validation_0-rmse:0.71304	validation_1-rmse:0.94881
# [421]	validation_0-rmse:0.71297	validation_1-rmse:0.94879
# [422]	validation_0-rmse:0.71291	validation_1-rmse:0.94895
# [423]	validation_0-rmse:0.71286	validation_1-rmse:0.94897
# [424]	validation_0-rmse:0.71270	validation_1-rmse:0.94926
# [425]	validation_0-rmse:0.71263	validation_1-rmse:0.94926
# [426]	validation_0-rmse:0.71260	validation_1-rmse:0.94920
# [427]	validation_0-rmse:0.71250	validation_1-rmse:0.94899
# [428]	validation_0-rmse:0.71247	validation_1-rmse:0.94902
# [429]	validation_0-rmse:0.71217	validation_1-rmse:0.94892
# [430]	validation_0-rmse:0.71207	validation_1-rmse:0.94903
# [431]	validation_0-rmse:0.71160	validation_1-rmse:0.94881
# [432]	validation_0-rmse:0.71156	validation_1-rmse:0.94892
# [433]	validation_0-rmse:0.71149	validation_1-rmse:0.94892
# [434]	validation_0-rmse:0.71137	validation_1-rmse:0.94897
# [435]	validation_0-rmse:0.71128	validation_1-rmse:0.94865
# [436]	validation_0-rmse:0.71095	validation_1-rmse:0.94693
# [437]	validation_0-rmse:0.71087	validation_1-rmse:0.94712
# [438]	validation_0-rmse:0.71078	validation_1-rmse:0.94694
# [439]	validation_0-rmse:0.71068	validation_1-rmse:0.94681
# [440]	validation_0-rmse:0.71064	validation_1-rmse:0.94702
# [441]	validation_0-rmse:0.71058	validation_1-rmse:0.94693
# [442]	validation_0-rmse:0.71052	validation_1-rmse:0.94719
# [443]	validation_0-rmse:0.71047	validation_1-rmse:0.94677
# [444]	validation_0-rmse:0.71042	validation_1-rmse:0.94682
# [445]	validation_0-rmse:0.71029	validation_1-rmse:0.94690
# [446]	validation_0-rmse:0.71022	validation_1-rmse:0.94702
# [447]	validation_0-rmse:0.71015	validation_1-rmse:0.94720
# [448]	validation_0-rmse:0.71007	validation_1-rmse:0.94704
# [449]	validation_0-rmse:0.71000	validation_1-rmse:0.94701
# [450]	validation_0-rmse:0.70995	validation_1-rmse:0.94709
# [451]	validation_0-rmse:0.70985	validation_1-rmse:0.94728
# [452]	validation_0-rmse:0.70981	validation_1-rmse:0.94725
# [453]	validation_0-rmse:0.70977	validation_1-rmse:0.94736
# [454]	validation_0-rmse:0.70966	validation_1-rmse:0.94719
# [455]	validation_0-rmse:0.70960	validation_1-rmse:0.94787
# [456]	validation_0-rmse:0.70955	validation_1-rmse:0.94795
# [457]	validation_0-rmse:0.70788	validation_1-rmse:0.95193
# [458]	validation_0-rmse:0.70777	validation_1-rmse:0.95214
# [459]	validation_0-rmse:0.70768	validation_1-rmse:0.95224
# [460]	validation_0-rmse:0.70762	validation_1-rmse:0.95188
# [461]	validation_0-rmse:0.70758	validation_1-rmse:0.95195
# [462]	validation_0-rmse:0.70754	validation_1-rmse:0.95192
# [463]	validation_0-rmse:0.70747	validation_1-rmse:0.95195
# [464]	validation_0-rmse:0.70741	validation_1-rmse:0.95187
# [465]	validation_0-rmse:0.70737	validation_1-rmse:0.95186
# [466]	validation_0-rmse:0.70733	validation_1-rmse:0.95188
# [467]	validation_0-rmse:0.70728	validation_1-rmse:0.95188
# [468]	validation_0-rmse:0.70718	validation_1-rmse:0.95187
# [469]	validation_0-rmse:0.70709	validation_1-rmse:0.95084
# [470]	validation_0-rmse:0.70697	validation_1-rmse:0.95112
# [471]	validation_0-rmse:0.70670	validation_1-rmse:0.95122
# [472]	validation_0-rmse:0.70664	validation_1-rmse:0.95129
# [473]	validation_0-rmse:0.70661	validation_1-rmse:0.95121
# [474]	validation_0-rmse:0.70625	validation_1-rmse:0.95118
# [475]	validation_0-rmse:0.70622	validation_1-rmse:0.95125
# [476]	validation_0-rmse:0.70618	validation_1-rmse:0.95134
# [477]	validation_0-rmse:0.70610	validation_1-rmse:0.95143
# [478]	validation_0-rmse:0.70602	validation_1-rmse:0.95137
# [479]	validation_0-rmse:0.70599	validation_1-rmse:0.95139
# [480]	validation_0-rmse:0.70593	validation_1-rmse:0.95145
# [481]	validation_0-rmse:0.70588	validation_1-rmse:0.95145
# [482]	validation_0-rmse:0.70585	validation_1-rmse:0.95137
# [483]	validation_0-rmse:0.70582	validation_1-rmse:0.95171
# [484]	validation_0-rmse:0.70573	validation_1-rmse:0.95154
# [485]	validation_0-rmse:0.70563	validation_1-rmse:0.95146
# [486]	validation_0-rmse:0.70524	validation_1-rmse:0.95112
# [487]	validation_0-rmse:0.70511	validation_1-rmse:0.95081
# [488]	validation_0-rmse:0.70497	validation_1-rmse:0.95050
# [489]	validation_0-rmse:0.70493	validation_1-rmse:0.95067
# [490]	validation_0-rmse:0.70481	validation_1-rmse:0.95050
# [491]	validation_0-rmse:0.70478	validation_1-rmse:0.95073
# [492]	validation_0-rmse:0.70466	validation_1-rmse:0.95067
# [493]	validation_0-rmse:0.70444	validation_1-rmse:0.95027
# [494]	validation_0-rmse:0.70436	validation_1-rmse:0.95088
# [495]	validation_0-rmse:0.70430	validation_1-rmse:0.95092
# [496]	validation_0-rmse:0.70420	validation_1-rmse:0.95126
# [497]	validation_0-rmse:0.70413	validation_1-rmse:0.95143
# [498]	validation_0-rmse:0.70405	validation_1-rmse:0.95136
# [499]	validation_0-rmse:0.70400	validation_1-rmse:0.95131
# [500]	validation_0-rmse:0.70391	validation_1-rmse:0.95133
# [501]	validation_0-rmse:0.70387	validation_1-rmse:0.95132
# [502]	validation_0-rmse:0.70383	validation_1-rmse:0.95138
# [503]	validation_0-rmse:0.70378	validation_1-rmse:0.95136
# [504]	validation_0-rmse:0.70374	validation_1-rmse:0.95141
# [505]	validation_0-rmse:0.70364	validation_1-rmse:0.95133
# [506]	validation_0-rmse:0.70361	validation_1-rmse:0.95110
# [507]	validation_0-rmse:0.70355	validation_1-rmse:0.95102
# [508]	validation_0-rmse:0.70351	validation_1-rmse:0.95099
# [509]	validation_0-rmse:0.70346	validation_1-rmse:0.95106
# [510]	validation_0-rmse:0.70340	validation_1-rmse:0.95104
# [511]	validation_0-rmse:0.70333	validation_1-rmse:0.95123
# [512]	validation_0-rmse:0.70318	validation_1-rmse:0.95126
# [513]	validation_0-rmse:0.70315	validation_1-rmse:0.95154
# [514]	validation_0-rmse:0.70308	validation_1-rmse:0.95140
# [515]	validation_0-rmse:0.70302	validation_1-rmse:0.95146
# [516]	validation_0-rmse:0.70292	validation_1-rmse:0.95154
# [517]	validation_0-rmse:0.70275	validation_1-rmse:0.95163
# [518]	validation_0-rmse:0.70271	validation_1-rmse:0.95160
# [519]	validation_0-rmse:0.70261	validation_1-rmse:0.95154
# [520]	validation_0-rmse:0.70256	validation_1-rmse:0.95150
# [521]	validation_0-rmse:0.70251	validation_1-rmse:0.95155
# [522]	validation_0-rmse:0.70244	validation_1-rmse:0.95156
# [523]	validation_0-rmse:0.70239	validation_1-rmse:0.95177
# [524]	validation_0-rmse:0.70234	validation_1-rmse:0.95174
# [525]	validation_0-rmse:0.70231	validation_1-rmse:0.95182
# [526]	validation_0-rmse:0.70226	validation_1-rmse:0.95205
# [527]	validation_0-rmse:0.70221	validation_1-rmse:0.95200
# [528]	validation_0-rmse:0.70130	validation_1-rmse:0.95286
# [529]	validation_0-rmse:0.70125	validation_1-rmse:0.95266
# [530]	validation_0-rmse:0.70116	validation_1-rmse:0.95254
# [531]	validation_0-rmse:0.70077	validation_1-rmse:0.94968
# [532]	validation_0-rmse:0.70071	validation_1-rmse:0.94971
# [533]	validation_0-rmse:0.70058	validation_1-rmse:0.94947
# [534]	validation_0-rmse:0.70051	validation_1-rmse:0.94957
# [535]	validation_0-rmse:0.70043	validation_1-rmse:0.94982
# [536]	validation_0-rmse:0.70036	validation_1-rmse:0.94973
# [537]	validation_0-rmse:0.70026	validation_1-rmse:0.94959
# [538]	validation_0-rmse:0.70020	validation_1-rmse:0.94964
# [539]	validation_0-rmse:0.70015	validation_1-rmse:0.94972
# [540]	validation_0-rmse:0.70008	validation_1-rmse:0.94965
# [541]	validation_0-rmse:0.70001	validation_1-rmse:0.94978
# [542]	validation_0-rmse:0.69995	validation_1-rmse:0.94975
# [543]	validation_0-rmse:0.69990	validation_1-rmse:0.94970
# [544]	validation_0-rmse:0.69985	validation_1-rmse:0.95010
# [545]	validation_0-rmse:0.69981	validation_1-rmse:0.95002
# [546]	validation_0-rmse:0.69975	validation_1-rmse:0.94990
# [547]	validation_0-rmse:0.69971	validation_1-rmse:0.94972
# [548]	validation_0-rmse:0.69964	validation_1-rmse:0.94985
# [549]	validation_0-rmse:0.69960	validation_1-rmse:0.94975
# [550]	validation_0-rmse:0.69955	validation_1-rmse:0.94951
# [551]	validation_0-rmse:0.69948	validation_1-rmse:0.94961
# [552]	validation_0-rmse:0.69943	validation_1-rmse:0.94968
# [553]	validation_0-rmse:0.69940	validation_1-rmse:0.94978
# [554]	validation_0-rmse:0.69936	validation_1-rmse:0.94962
# [555]	validation_0-rmse:0.69922	validation_1-rmse:0.95013
# [556]	validation_0-rmse:0.69919	validation_1-rmse:0.94998
# [557]	validation_0-rmse:0.69911	validation_1-rmse:0.95002
# [558]	validation_0-rmse:0.69854	validation_1-rmse:0.95119
# [559]	validation_0-rmse:0.69851	validation_1-rmse:0.95072
# [560]	validation_0-rmse:0.69842	validation_1-rmse:0.95079
# [561]	validation_0-rmse:0.69830	validation_1-rmse:0.95083
# [562]	validation_0-rmse:0.69824	validation_1-rmse:0.95069
# [563]	validation_0-rmse:0.69816	validation_1-rmse:0.95091
# [564]	validation_0-rmse:0.69813	validation_1-rmse:0.95065
# [565]	validation_0-rmse:0.69803	validation_1-rmse:0.95062
# [566]	validation_0-rmse:0.69798	validation_1-rmse:0.95082
# [567]	validation_0-rmse:0.69793	validation_1-rmse:0.95079
# [568]	validation_0-rmse:0.69783	validation_1-rmse:0.95090
# [569]	validation_0-rmse:0.69780	validation_1-rmse:0.95092
# [570]	validation_0-rmse:0.69772	validation_1-rmse:0.95097
# [571]	validation_0-rmse:0.69767	validation_1-rmse:0.95091
# [572]	validation_0-rmse:0.69752	validation_1-rmse:0.95092
# [573]	validation_0-rmse:0.69744	validation_1-rmse:0.95051
# [574]	validation_0-rmse:0.69741	validation_1-rmse:0.95028
# [575]	validation_0-rmse:0.69734	validation_1-rmse:0.95025
# [576]	validation_0-rmse:0.69725	validation_1-rmse:0.95007
# [577]	validation_0-rmse:0.69720	validation_1-rmse:0.95012
# [578]	validation_0-rmse:0.69716	validation_1-rmse:0.95019
# [579]	validation_0-rmse:0.69700	validation_1-rmse:0.95039
# [580]	validation_0-rmse:0.69695	validation_1-rmse:0.95035
# [581]	validation_0-rmse:0.69692	validation_1-rmse:0.95030
# [582]	validation_0-rmse:0.69688	validation_1-rmse:0.95033
# [583]	validation_0-rmse:0.69684	validation_1-rmse:0.95058
# [584]	validation_0-rmse:0.69679	validation_1-rmse:0.95058
# [585]	validation_0-rmse:0.69675	validation_1-rmse:0.95075
# [586]	validation_0-rmse:0.69669	validation_1-rmse:0.95078
# [587]	validation_0-rmse:0.69664	validation_1-rmse:0.95094
# [588]	validation_0-rmse:0.69658	validation_1-rmse:0.95100
# [589]	validation_0-rmse:0.69651	validation_1-rmse:0.95109
# [590]	validation_0-rmse:0.69640	validation_1-rmse:0.95130
# [591]	validation_0-rmse:0.69634	validation_1-rmse:0.95148
# [592]	validation_0-rmse:0.69615	validation_1-rmse:0.95147
# [593]	validation_0-rmse:0.69606	validation_1-rmse:0.95163
# [594]	validation_0-rmse:0.69599	validation_1-rmse:0.95197
# [595]	validation_0-rmse:0.69595	validation_1-rmse:0.95193
# [596]	validation_0-rmse:0.69590	validation_1-rmse:0.95198
# [597]	validation_0-rmse:0.69584	validation_1-rmse:0.95198
# [598]	validation_0-rmse:0.69581	validation_1-rmse:0.95199
# [599]	validation_0-rmse:0.69576	validation_1-rmse:0.95218
# [600]	validation_0-rmse:0.69572	validation_1-rmse:0.95225
# [601]	validation_0-rmse:0.69560	validation_1-rmse:0.95167
# [602]	validation_0-rmse:0.69553	validation_1-rmse:0.95152
# [603]	validation_0-rmse:0.69548	validation_1-rmse:0.95154
# [604]	validation_0-rmse:0.69541	validation_1-rmse:0.95156
# [605]	validation_0-rmse:0.69537	validation_1-rmse:0.95165
# [606]	validation_0-rmse:0.69535	validation_1-rmse:0.95158
# [607]	validation_0-rmse:0.69530	validation_1-rmse:0.95147
# [608]	validation_0-rmse:0.69526	validation_1-rmse:0.95136
# [609]	validation_0-rmse:0.69523	validation_1-rmse:0.95157
# [610]	validation_0-rmse:0.69519	validation_1-rmse:0.95150
# [611]	validation_0-rmse:0.69511	validation_1-rmse:0.95130
# [612]	validation_0-rmse:0.69504	validation_1-rmse:0.95162
# [613]	validation_0-rmse:0.69487	validation_1-rmse:0.95226
# [614]	validation_0-rmse:0.69483	validation_1-rmse:0.95220
# [615]	validation_0-rmse:0.69472	validation_1-rmse:0.95226
# [616]	validation_0-rmse:0.69464	validation_1-rmse:0.95247
# [617]	validation_0-rmse:0.69462	validation_1-rmse:0.95243
# [618]	validation_0-rmse:0.69455	validation_1-rmse:0.95235
# [619]	validation_0-rmse:0.69446	validation_1-rmse:0.95234
# [620]	validation_0-rmse:0.69442	validation_1-rmse:0.95221
# [621]	validation_0-rmse:0.69439	validation_1-rmse:0.95231
# [622]	validation_0-rmse:0.69435	validation_1-rmse:0.95213
# [623]	validation_0-rmse:0.69428	validation_1-rmse:0.95207
# [624]	validation_0-rmse:0.69425	validation_1-rmse:0.95210
# [625]	validation_0-rmse:0.69417	validation_1-rmse:0.95221
# [626]	validation_0-rmse:0.69411	validation_1-rmse:0.95209
# [627]	validation_0-rmse:0.69398	validation_1-rmse:0.95194
# [628]	validation_0-rmse:0.69395	validation_1-rmse:0.95185
# [629]	validation_0-rmse:0.69385	validation_1-rmse:0.95174
# [630]	validation_0-rmse:0.69371	validation_1-rmse:0.95154
# [631]	validation_0-rmse:0.69365	validation_1-rmse:0.95171
# [632]	validation_0-rmse:0.69361	validation_1-rmse:0.95175
# [633]	validation_0-rmse:0.69355	validation_1-rmse:0.95170
# [634]	validation_0-rmse:0.69266	validation_1-rmse:0.95126
# [635]	validation_0-rmse:0.69260	validation_1-rmse:0.95158
# [636]	validation_0-rmse:0.69249	validation_1-rmse:0.95172
# [637]	validation_0-rmse:0.69241	validation_1-rmse:0.95175
# [638]	validation_0-rmse:0.69228	validation_1-rmse:0.95182
# [639]	validation_0-rmse:0.69222	validation_1-rmse:0.95187
# [640]	validation_0-rmse:0.69215	validation_1-rmse:0.95203
# [641]	validation_0-rmse:0.69193	validation_1-rmse:0.95210
# [642]	validation_0-rmse:0.69188	validation_1-rmse:0.95211
# [643]	validation_0-rmse:0.69182	validation_1-rmse:0.95203
# [644]	validation_0-rmse:0.69174	validation_1-rmse:0.95200
# [645]	validation_0-rmse:0.69167	validation_1-rmse:0.95215
# [646]	validation_0-rmse:0.69162	validation_1-rmse:0.95206
# [647]	validation_0-rmse:0.69158	validation_1-rmse:0.95206
# [648]	validation_0-rmse:0.69152	validation_1-rmse:0.95201
# [649]	validation_0-rmse:0.69148	validation_1-rmse:0.95193
# [650]	validation_0-rmse:0.69143	validation_1-rmse:0.95182
# [651]	validation_0-rmse:0.69142	validation_1-rmse:0.95179
# [652]	validation_0-rmse:0.69138	validation_1-rmse:0.95235
# [653]	validation_0-rmse:0.69133	validation_1-rmse:0.95222
# [654]	validation_0-rmse:0.69120	validation_1-rmse:0.95246
# [655]	validation_0-rmse:0.69112	validation_1-rmse:0.95248
# [656]	validation_0-rmse:0.69108	validation_1-rmse:0.95251
# [657]	validation_0-rmse:0.69104	validation_1-rmse:0.95242
# [658]	validation_0-rmse:0.69103	validation_1-rmse:0.95252
# [659]	validation_0-rmse:0.69098	validation_1-rmse:0.95232
# [660]	validation_0-rmse:0.69091	validation_1-rmse:0.95197
# [661]	validation_0-rmse:0.69087	validation_1-rmse:0.95209
# [662]	validation_0-rmse:0.69082	validation_1-rmse:0.95227
# [663]	validation_0-rmse:0.69076	validation_1-rmse:0.95234
# [664]	validation_0-rmse:0.69071	validation_1-rmse:0.95230
# [665]	validation_0-rmse:0.69063	validation_1-rmse:0.95233
# [666]	validation_0-rmse:0.69059	validation_1-rmse:0.95221
# [667]	validation_0-rmse:0.69055	validation_1-rmse:0.95207
# [668]	validation_0-rmse:0.69051	validation_1-rmse:0.95201
# [669]	validation_0-rmse:0.69041	validation_1-rmse:0.95203
# [670]	validation_0-rmse:0.69033	validation_1-rmse:0.95210
# [671]	validation_0-rmse:0.69030	validation_1-rmse:0.95217
# [672]	validation_0-rmse:0.69025	validation_1-rmse:0.95220
# [673]	validation_0-rmse:0.69022	validation_1-rmse:0.95230
# [674]	validation_0-rmse:0.69003	validation_1-rmse:0.95238
# [675]	validation_0-rmse:0.68997	validation_1-rmse:0.95235
# [676]	validation_0-rmse:0.68994	validation_1-rmse:0.95253
# [677]	validation_0-rmse:0.68988	validation_1-rmse:0.95270
# [678]	validation_0-rmse:0.68986	validation_1-rmse:0.95276
# [679]	validation_0-rmse:0.68983	validation_1-rmse:0.95275
# [680]	validation_0-rmse:0.68976	validation_1-rmse:0.95249
# [681]	validation_0-rmse:0.68940	validation_1-rmse:0.95230
# [682]	validation_0-rmse:0.68936	validation_1-rmse:0.95243
# [683]	validation_0-rmse:0.68928	validation_1-rmse:0.95221
# [684]	validation_0-rmse:0.68924	validation_1-rmse:0.95229
# [685]	validation_0-rmse:0.68919	validation_1-rmse:0.95246
# [686]	validation_0-rmse:0.68915	validation_1-rmse:0.95246
# [687]	validation_0-rmse:0.68911	validation_1-rmse:0.95242
# [688]	validation_0-rmse:0.68905	validation_1-rmse:0.95219
# [689]	validation_0-rmse:0.68901	validation_1-rmse:0.95213
# [690]	validation_0-rmse:0.68896	validation_1-rmse:0.95219
# [691]	validation_0-rmse:0.68886	validation_1-rmse:0.95209
# [692]	validation_0-rmse:0.68880	validation_1-rmse:0.95246
# [693]	validation_0-rmse:0.68872	validation_1-rmse:0.95246
# [694]	validation_0-rmse:0.68851	validation_1-rmse:0.95225
# [695]	validation_0-rmse:0.68848	validation_1-rmse:0.95220
# [696]	validation_0-rmse:0.68845	validation_1-rmse:0.95210
# [697]	validation_0-rmse:0.68839	validation_1-rmse:0.95188
# [698]	validation_0-rmse:0.68836	validation_1-rmse:0.95175
# [699]	validation_0-rmse:0.68828	validation_1-rmse:0.95180
# [700]	validation_0-rmse:0.68817	validation_1-rmse:0.95177
# [701]	validation_0-rmse:0.68814	validation_1-rmse:0.95169
# [702]	validation_0-rmse:0.68799	validation_1-rmse:0.95185
# [703]	validation_0-rmse:0.68783	validation_1-rmse:0.95209
# [704]	validation_0-rmse:0.68776	validation_1-rmse:0.95204
# [705]	validation_0-rmse:0.68772	validation_1-rmse:0.95198
# [706]	validation_0-rmse:0.68766	validation_1-rmse:0.95204
# [707]	validation_0-rmse:0.68761	validation_1-rmse:0.95203
# [708]	validation_0-rmse:0.68754	validation_1-rmse:0.95201
# [709]	validation_0-rmse:0.68748	validation_1-rmse:0.95203
# [710]	validation_0-rmse:0.68742	validation_1-rmse:0.95229
# [711]	validation_0-rmse:0.68735	validation_1-rmse:0.95243
# [712]	validation_0-rmse:0.68720	validation_1-rmse:0.95239
# [713]	validation_0-rmse:0.68714	validation_1-rmse:0.95237
# [714]	validation_0-rmse:0.68711	validation_1-rmse:0.95239
# [715]	validation_0-rmse:0.68706	validation_1-rmse:0.95232
# [716]	validation_0-rmse:0.68699	validation_1-rmse:0.95237
# [717]	validation_0-rmse:0.68694	validation_1-rmse:0.95258
# [718]	validation_0-rmse:0.68688	validation_1-rmse:0.95249
# [719]	validation_0-rmse:0.68678	validation_1-rmse:0.95297
# [720]	validation_0-rmse:0.68673	validation_1-rmse:0.95301
# [721]	validation_0-rmse:0.68661	validation_1-rmse:0.95300
# [722]	validation_0-rmse:0.68654	validation_1-rmse:0.95294
# [723]	validation_0-rmse:0.68650	validation_1-rmse:0.95300
# [724]	validation_0-rmse:0.68647	validation_1-rmse:0.95284
# [725]	validation_0-rmse:0.68643	validation_1-rmse:0.95283
# [726]	validation_0-rmse:0.68640	validation_1-rmse:0.95216
# [727]	validation_0-rmse:0.68633	validation_1-rmse:0.95219
# [728]	validation_0-rmse:0.68628	validation_1-rmse:0.95206
# [729]	validation_0-rmse:0.68624	validation_1-rmse:0.95209
# [730]	validation_0-rmse:0.68619	validation_1-rmse:0.95218
# [731]	validation_0-rmse:0.68615	validation_1-rmse:0.95234
# [732]	validation_0-rmse:0.68613	validation_1-rmse:0.95235
# [733]	validation_0-rmse:0.68609	validation_1-rmse:0.95204
# [734]	validation_0-rmse:0.68604	validation_1-rmse:0.95221
# [735]	validation_0-rmse:0.68597	validation_1-rmse:0.95252
# [736]	validation_0-rmse:0.68593	validation_1-rmse:0.95248
# [737]	validation_0-rmse:0.68587	validation_1-rmse:0.95263
# [738]	validation_0-rmse:0.68581	validation_1-rmse:0.95279
# [739]	validation_0-rmse:0.68562	validation_1-rmse:0.95292
# [740]	validation_0-rmse:0.68549	validation_1-rmse:0.95282
# [741]	validation_0-rmse:0.68545	validation_1-rmse:0.95270
# [742]	validation_0-rmse:0.68542	validation_1-rmse:0.95282
# [743]	validation_0-rmse:0.68532	validation_1-rmse:0.95279
# [744]	validation_0-rmse:0.68526	validation_1-rmse:0.95266
# [745]	validation_0-rmse:0.68522	validation_1-rmse:0.95308
# [746]	validation_0-rmse:0.68497	validation_1-rmse:0.95315
# [747]	validation_0-rmse:0.68488	validation_1-rmse:0.95319
# [748]	validation_0-rmse:0.68482	validation_1-rmse:0.95329
# [749]	validation_0-rmse:0.68480	validation_1-rmse:0.95323
# [750]	validation_0-rmse:0.68467	validation_1-rmse:0.95328
# [751]	validation_0-rmse:0.68463	validation_1-rmse:0.95312
# [752]	validation_0-rmse:0.68459	validation_1-rmse:0.95325
# [753]	validation_0-rmse:0.68453	validation_1-rmse:0.95321
# [754]	validation_0-rmse:0.68449	validation_1-rmse:0.95327
# [755]	validation_0-rmse:0.68447	validation_1-rmse:0.95312
# [756]	validation_0-rmse:0.68444	validation_1-rmse:0.95320
# [757]	validation_0-rmse:0.68441	validation_1-rmse:0.95327
# [758]	validation_0-rmse:0.68437	validation_1-rmse:0.95331
# [759]	validation_0-rmse:0.68433	validation_1-rmse:0.95344
# [760]	validation_0-rmse:0.68431	validation_1-rmse:0.95356
# [761]	validation_0-rmse:0.68354	validation_1-rmse:0.95499
# [762]	validation_0-rmse:0.68347	validation_1-rmse:0.95506
# [763]	validation_0-rmse:0.68340	validation_1-rmse:0.95477
# [764]	validation_0-rmse:0.68336	validation_1-rmse:0.95471
# [765]	validation_0-rmse:0.68331	validation_1-rmse:0.95481
# [766]	validation_0-rmse:0.68328	validation_1-rmse:0.95441
# [767]	validation_0-rmse:0.68325	validation_1-rmse:0.95444
# [768]	validation_0-rmse:0.68320	validation_1-rmse:0.95451
# [769]	validation_0-rmse:0.68315	validation_1-rmse:0.95456
# [770]	validation_0-rmse:0.68309	validation_1-rmse:0.95468
# [771]	validation_0-rmse:0.68303	validation_1-rmse:0.95462
# [772]	validation_0-rmse:0.68299	validation_1-rmse:0.95455
# [773]	validation_0-rmse:0.68294	validation_1-rmse:0.95467
# [774]	validation_0-rmse:0.68289	validation_1-rmse:0.95452
# [775]	validation_0-rmse:0.68285	validation_1-rmse:0.95449
# [776]	validation_0-rmse:0.68278	validation_1-rmse:0.95428
# [777]	validation_0-rmse:0.68273	validation_1-rmse:0.95427
# [778]	validation_0-rmse:0.68270	validation_1-rmse:0.95429
# [779]	validation_0-rmse:0.68264	validation_1-rmse:0.95443
# [780]	validation_0-rmse:0.68257	validation_1-rmse:0.95451
# [781]	validation_0-rmse:0.68253	validation_1-rmse:0.95461
# [782]	validation_0-rmse:0.68239	validation_1-rmse:0.95446
# [783]	validation_0-rmse:0.68214	validation_1-rmse:0.95475
# [784]	validation_0-rmse:0.68209	validation_1-rmse:0.95476
# [785]	validation_0-rmse:0.68203	validation_1-rmse:0.95485
# [786]	validation_0-rmse:0.68169	validation_1-rmse:0.95422
# [787]	validation_0-rmse:0.68164	validation_1-rmse:0.95432
# [788]	validation_0-rmse:0.68119	validation_1-rmse:0.95483
# [789]	validation_0-rmse:0.68112	validation_1-rmse:0.95473
# [790]	validation_0-rmse:0.68105	validation_1-rmse:0.95464
# [791]	validation_0-rmse:0.68098	validation_1-rmse:0.95463
# [792]	validation_0-rmse:0.68094	validation_1-rmse:0.95465
# [793]	validation_0-rmse:0.68089	validation_1-rmse:0.95462
# [794]	validation_0-rmse:0.68049	validation_1-rmse:0.95852
# [795]	validation_0-rmse:0.68044	validation_1-rmse:0.95836
# [796]	validation_0-rmse:0.68027	validation_1-rmse:0.95851
# [797]	validation_0-rmse:0.68024	validation_1-rmse:0.95857
# [798]	validation_0-rmse:0.68020	validation_1-rmse:0.95863
# [799]	validation_0-rmse:0.68011	validation_1-rmse:0.95869
# [800]	validation_0-rmse:0.68006	validation_1-rmse:0.95879
# [801]	validation_0-rmse:0.68001	validation_1-rmse:0.95885
# [802]	validation_0-rmse:0.67997	validation_1-rmse:0.95881
# [803]	validation_0-rmse:0.67992	validation_1-rmse:0.95849
# [804]	validation_0-rmse:0.67987	validation_1-rmse:0.95884
# [805]	validation_0-rmse:0.67983	validation_1-rmse:0.95926
# [806]	validation_0-rmse:0.67976	validation_1-rmse:0.95945
# [807]	validation_0-rmse:0.67966	validation_1-rmse:0.95916
# [808]	validation_0-rmse:0.67953	validation_1-rmse:0.95924
# [809]	validation_0-rmse:0.67950	validation_1-rmse:0.95912
# [810]	validation_0-rmse:0.67944	validation_1-rmse:0.95911
# [811]	validation_0-rmse:0.67940	validation_1-rmse:0.95919
# [812]	validation_0-rmse:0.67937	validation_1-rmse:0.95893
# [813]	validation_0-rmse:0.67926	validation_1-rmse:0.95919
# [814]	validation_0-rmse:0.67896	validation_1-rmse:0.96635
# [815]	validation_0-rmse:0.67891	validation_1-rmse:0.96611
# [816]	validation_0-rmse:0.67884	validation_1-rmse:0.96600
# [817]	validation_0-rmse:0.67876	validation_1-rmse:0.96596
# [818]	validation_0-rmse:0.67861	validation_1-rmse:0.96719
# [819]	validation_0-rmse:0.67855	validation_1-rmse:0.96700
# [820]	validation_0-rmse:0.67847	validation_1-rmse:0.96688
# [821]	validation_0-rmse:0.67837	validation_1-rmse:0.96673
# [822]	validation_0-rmse:0.67834	validation_1-rmse:0.96677
# [823]	validation_0-rmse:0.67830	validation_1-rmse:0.96685
# [824]	validation_0-rmse:0.67826	validation_1-rmse:0.96655
# [825]	validation_0-rmse:0.67823	validation_1-rmse:0.96638
# [826]	validation_0-rmse:0.67819	validation_1-rmse:0.96632
# [827]	validation_0-rmse:0.67816	validation_1-rmse:0.96635
# [828]	validation_0-rmse:0.67812	validation_1-rmse:0.96644
# [829]	validation_0-rmse:0.67811	validation_1-rmse:0.96673
# [830]	validation_0-rmse:0.67808	validation_1-rmse:0.96708
# [831]	validation_0-rmse:0.67804	validation_1-rmse:0.96726
# [832]	validation_0-rmse:0.67797	validation_1-rmse:0.96721
# [833]	validation_0-rmse:0.67795	validation_1-rmse:0.96716
# [834]	validation_0-rmse:0.67791	validation_1-rmse:0.96717
# [835]	validation_0-rmse:0.67787	validation_1-rmse:0.96718
# [836]	validation_0-rmse:0.67781	validation_1-rmse:0.96709
# [837]	validation_0-rmse:0.67777	validation_1-rmse:0.96713
# [838]	validation_0-rmse:0.67771	validation_1-rmse:0.96714
# [839]	validation_0-rmse:0.67763	validation_1-rmse:0.96716
# [840]	validation_0-rmse:0.67758	validation_1-rmse:0.96718
# [841]	validation_0-rmse:0.67756	validation_1-rmse:0.96733
# [842]	validation_0-rmse:0.67754	validation_1-rmse:0.96744
# [843]	validation_0-rmse:0.67752	validation_1-rmse:0.96766
# [844]	validation_0-rmse:0.67749	validation_1-rmse:0.96764
# [845]	validation_0-rmse:0.67746	validation_1-rmse:0.96758
# [846]	validation_0-rmse:0.67741	validation_1-rmse:0.96750
# [847]	validation_0-rmse:0.67735	validation_1-rmse:0.96742
# [848]	validation_0-rmse:0.67733	validation_1-rmse:0.96728
# [849]	validation_0-rmse:0.67727	validation_1-rmse:0.96740
# [850]	validation_0-rmse:0.67725	validation_1-rmse:0.96751
# [851]	validation_0-rmse:0.67718	validation_1-rmse:0.96755
# [852]	validation_0-rmse:0.67715	validation_1-rmse:0.96777
# [853]	validation_0-rmse:0.67692	validation_1-rmse:0.96787
# [854]	validation_0-rmse:0.67687	validation_1-rmse:0.96788
# [855]	validation_0-rmse:0.67684	validation_1-rmse:0.96773
# [856]	validation_0-rmse:0.67680	validation_1-rmse:0.96763
# [857]	validation_0-rmse:0.67620	validation_1-rmse:0.96773
# [858]	validation_0-rmse:0.67616	validation_1-rmse:0.96780
# [859]	validation_0-rmse:0.67613	validation_1-rmse:0.96782
# [860]	validation_0-rmse:0.67609	validation_1-rmse:0.96779
# [861]	validation_0-rmse:0.67606	validation_1-rmse:0.96803
# [862]	validation_0-rmse:0.67603	validation_1-rmse:0.96801
# [863]	validation_0-rmse:0.67600	validation_1-rmse:0.96812
# [864]	validation_0-rmse:0.67596	validation_1-rmse:0.96804
# [865]	validation_0-rmse:0.67571	validation_1-rmse:0.96854
# [866]	validation_0-rmse:0.67566	validation_1-rmse:0.96848
# [867]	validation_0-rmse:0.67563	validation_1-rmse:0.96851
# [868]	validation_0-rmse:0.67559	validation_1-rmse:0.96829
# [869]	validation_0-rmse:0.67555	validation_1-rmse:0.96800
# [870]	validation_0-rmse:0.67553	validation_1-rmse:0.96812
# [871]	validation_0-rmse:0.67548	validation_1-rmse:0.96816
# [872]	validation_0-rmse:0.67546	validation_1-rmse:0.96821
# [873]	validation_0-rmse:0.67540	validation_1-rmse:0.96827
# [874]	validation_0-rmse:0.67535	validation_1-rmse:0.96838
# [875]	validation_0-rmse:0.67532	validation_1-rmse:0.96822
# [876]	validation_0-rmse:0.67528	validation_1-rmse:0.96817
# [877]	validation_0-rmse:0.67524	validation_1-rmse:0.96813
# [878]	validation_0-rmse:0.67521	validation_1-rmse:0.96802
# [879]	validation_0-rmse:0.67516	validation_1-rmse:0.96823
# [880]	validation_0-rmse:0.67510	validation_1-rmse:0.96809
# [881]	validation_0-rmse:0.67506	validation_1-rmse:0.96819
# [882]	validation_0-rmse:0.67504	validation_1-rmse:0.96834
# [883]	validation_0-rmse:0.67495	validation_1-rmse:0.96826
# [884]	validation_0-rmse:0.67491	validation_1-rmse:0.96839
# [885]	validation_0-rmse:0.67488	validation_1-rmse:0.96845
# [886]	validation_0-rmse:0.67486	validation_1-rmse:0.96841
# [887]	validation_0-rmse:0.67484	validation_1-rmse:0.96833
# [888]	validation_0-rmse:0.67444	validation_1-rmse:0.97016
# [889]	validation_0-rmse:0.67439	validation_1-rmse:0.97029
# [890]	validation_0-rmse:0.67437	validation_1-rmse:0.97025
# [891]	validation_0-rmse:0.67433	validation_1-rmse:0.97009
# [892]	validation_0-rmse:0.67429	validation_1-rmse:0.97017
# [893]	validation_0-rmse:0.67426	validation_1-rmse:0.97028
# [894]	validation_0-rmse:0.67423	validation_1-rmse:0.97029
# [895]	validation_0-rmse:0.67418	validation_1-rmse:0.97032
# [896]	validation_0-rmse:0.67414	validation_1-rmse:0.97036
# [897]	validation_0-rmse:0.67408	validation_1-rmse:0.97046
# [898]	validation_0-rmse:0.67406	validation_1-rmse:0.97044
# [899]	validation_0-rmse:0.67404	validation_1-rmse:0.97037
# [900]	validation_0-rmse:0.67398	validation_1-rmse:0.97021
# [901]	validation_0-rmse:0.67393	validation_1-rmse:0.97000
# [902]	validation_0-rmse:0.67390	validation_1-rmse:0.97012
# [903]	validation_0-rmse:0.67386	validation_1-rmse:0.97005
# [904]	validation_0-rmse:0.67381	validation_1-rmse:0.96997
# [905]	validation_0-rmse:0.67377	validation_1-rmse:0.96990
# [906]	validation_0-rmse:0.67374	validation_1-rmse:0.96999
# [907]	validation_0-rmse:0.67371	validation_1-rmse:0.97002
# [908]	validation_0-rmse:0.67367	validation_1-rmse:0.97048
# [909]	validation_0-rmse:0.67363	validation_1-rmse:0.97029
# [910]	validation_0-rmse:0.67358	validation_1-rmse:0.97027
# [911]	validation_0-rmse:0.67355	validation_1-rmse:0.97034
# [912]	validation_0-rmse:0.67347	validation_1-rmse:0.97042
# [913]	validation_0-rmse:0.67342	validation_1-rmse:0.97029
# [914]	validation_0-rmse:0.67328	validation_1-rmse:0.97038
# [915]	validation_0-rmse:0.67320	validation_1-rmse:0.97060
# [916]	validation_0-rmse:0.67317	validation_1-rmse:0.97055
# [917]	validation_0-rmse:0.67313	validation_1-rmse:0.97052
# [918]	validation_0-rmse:0.67310	validation_1-rmse:0.97032
# [919]	validation_0-rmse:0.67306	validation_1-rmse:0.97013
# [920]	validation_0-rmse:0.67302	validation_1-rmse:0.97051
# [921]	validation_0-rmse:0.67298	validation_1-rmse:0.97041
# [922]	validation_0-rmse:0.67290	validation_1-rmse:0.97040
# [923]	validation_0-rmse:0.67287	validation_1-rmse:0.97049
# [924]	validation_0-rmse:0.67279	validation_1-rmse:0.97041
# [925]	validation_0-rmse:0.67275	validation_1-rmse:0.97026
# [926]	validation_0-rmse:0.67271	validation_1-rmse:0.97042
# [927]	validation_0-rmse:0.67267	validation_1-rmse:0.97034
# [928]	validation_0-rmse:0.67258	validation_1-rmse:0.97030
# [929]	validation_0-rmse:0.67252	validation_1-rmse:0.97026
# [930]	validation_0-rmse:0.67247	validation_1-rmse:0.96970
# [931]	validation_0-rmse:0.67242	validation_1-rmse:0.96969
# [932]	validation_0-rmse:0.67238	validation_1-rmse:0.96976
# [933]	validation_0-rmse:0.67235	validation_1-rmse:0.96992
# [934]	validation_0-rmse:0.67230	validation_1-rmse:0.96995
# [935]	validation_0-rmse:0.67225	validation_1-rmse:0.97016
# [936]	validation_0-rmse:0.67215	validation_1-rmse:0.97007
# [937]	validation_0-rmse:0.67213	validation_1-rmse:0.97000
# [938]	validation_0-rmse:0.67208	validation_1-rmse:0.96989
# [939]	validation_0-rmse:0.67206	validation_1-rmse:0.96996
# [940]	validation_0-rmse:0.67174	validation_1-rmse:0.96945
# [941]	validation_0-rmse:0.67172	validation_1-rmse:0.96930
# [942]	validation_0-rmse:0.67167	validation_1-rmse:0.96935
# [943]	validation_0-rmse:0.67162	validation_1-rmse:0.96934
# [944]	validation_0-rmse:0.67149	validation_1-rmse:0.96968
# [945]	validation_0-rmse:0.67146	validation_1-rmse:0.96975
# [946]	validation_0-rmse:0.67145	validation_1-rmse:0.96971
# [947]	validation_0-rmse:0.67142	validation_1-rmse:0.96982
# [948]	validation_0-rmse:0.67137	validation_1-rmse:0.96988
# [949]	validation_0-rmse:0.67133	validation_1-rmse:0.96993
# [950]	validation_0-rmse:0.67124	validation_1-rmse:0.96991
# [951]	validation_0-rmse:0.67120	validation_1-rmse:0.97000
# [952]	validation_0-rmse:0.67117	validation_1-rmse:0.97029
# [953]	validation_0-rmse:0.67114	validation_1-rmse:0.97022
# [954]	validation_0-rmse:0.67110	validation_1-rmse:0.97028
# [955]	validation_0-rmse:0.67103	validation_1-rmse:0.97021
# [956]	validation_0-rmse:0.67100	validation_1-rmse:0.97021
# [957]	validation_0-rmse:0.67097	validation_1-rmse:0.97023
# [958]	validation_0-rmse:0.67093	validation_1-rmse:0.97008
# [959]	validation_0-rmse:0.67090	validation_1-rmse:0.97026
# [960]	validation_0-rmse:0.67085	validation_1-rmse:0.97059
# [961]	validation_0-rmse:0.67078	validation_1-rmse:0.97050
# [962]	validation_0-rmse:0.67074	validation_1-rmse:0.97070
# [963]	validation_0-rmse:0.67068	validation_1-rmse:0.97066
# [964]	validation_0-rmse:0.67056	validation_1-rmse:0.97051
# [965]	validation_0-rmse:0.67053	validation_1-rmse:0.97044
# [966]	validation_0-rmse:0.67050	validation_1-rmse:0.97056
# [967]	validation_0-rmse:0.67043	validation_1-rmse:0.97062
# [968]	validation_0-rmse:0.67040	validation_1-rmse:0.97061
# [969]	validation_0-rmse:0.67032	validation_1-rmse:0.97053
# [970]	validation_0-rmse:0.67026	validation_1-rmse:0.97049
# [971]	validation_0-rmse:0.67023	validation_1-rmse:0.97058
# [972]	validation_0-rmse:0.67020	validation_1-rmse:0.97046
# [973]	validation_0-rmse:0.67017	validation_1-rmse:0.97047
# [974]	validation_0-rmse:0.67013	validation_1-rmse:0.97038
# [975]	validation_0-rmse:0.67008	validation_1-rmse:0.97036
# [976]	validation_0-rmse:0.67004	validation_1-rmse:0.97029
# [977]	validation_0-rmse:0.67001	validation_1-rmse:0.97023
# [978]	validation_0-rmse:0.66998	validation_1-rmse:0.97003
# [979]	validation_0-rmse:0.66995	validation_1-rmse:0.96997
# [980]	validation_0-rmse:0.66992	validation_1-rmse:0.96978
# [981]	validation_0-rmse:0.66965	validation_1-rmse:0.97069
# [982]	validation_0-rmse:0.66963	validation_1-rmse:0.97086
# [983]	validation_0-rmse:0.66959	validation_1-rmse:0.97083
# [984]	validation_0-rmse:0.66949	validation_1-rmse:0.97083
# [985]	validation_0-rmse:0.66947	validation_1-rmse:0.97078
# [986]	validation_0-rmse:0.66942	validation_1-rmse:0.97085
# [987]	validation_0-rmse:0.66937	validation_1-rmse:0.97087
# [988]	validation_0-rmse:0.66933	validation_1-rmse:0.97097
# [989]	validation_0-rmse:0.66928	validation_1-rmse:0.97117
# [990]	validation_0-rmse:0.66925	validation_1-rmse:0.97124
# [991]	validation_0-rmse:0.66921	validation_1-rmse:0.97112
# [992]	validation_0-rmse:0.66919	validation_1-rmse:0.97119
# [993]	validation_0-rmse:0.66914	validation_1-rmse:0.97100
# [994]	validation_0-rmse:0.66911	validation_1-rmse:0.97116
# [995]	validation_0-rmse:0.66907	validation_1-rmse:0.97109
# [996]	validation_0-rmse:0.66902	validation_1-rmse:0.97124
# [997]	validation_0-rmse:0.66900	validation_1-rmse:0.97121
# [998]	validation_0-rmse:0.66897	validation_1-rmse:0.97135
# [999]	validation_0-rmse:0.66892	validation_1-rmse:0.97136
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric='rmse', feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.3, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=8,
#              max_leaves=None, min_child_weight=300, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=1000,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
Y_pred = model.predict(X_valid).clip(0, 20)
Y_test = model.predict(X_test).clip(0, 20)

submission = pd.DataFrame({
    "ID": test.index, 
    "item_cnt_month": Y_test
})
submission.to_csv('xgb_submission.csv', index=False)

# save predictions for an ensemble
pickle.dump(Y_pred, open('xgb_train.pickle', 'wb'))
pickle.dump(Y_test, open('xgb_test.pickle', 'wb'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 Y_pred = model.predict(X_valid).clip(0, 20)
#       2 Y_test = model.predict(X_test).clip(0, 20)
#       4 submission = pd.DataFrame({
#       5     "ID": test.index,
#       6     "item_cnt_month": Y_test
#       7 })
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\core.py:2499, in Booster.predict(self, data, output_margin, pred_leaf, pred_contribs, approx_contribs, pred_interactions, validate_features, training, iteration_range, strict_shape)
#    2418 """Predict with data.  The full model will be used unless `iteration_range` is
#    2419 specified, meaning user have to either slice the model or use the
#    2420 ``best_iteration`` attribute to get prediction from best model returned from
#    (...)
#    2496
#    2497 """
#    2498 if not isinstance(data, DMatrix):
# -> 2499     raise TypeError("Expecting data to be a DMatrix object, got: ", type(data))
#    2500 if validate_features:
#    2501     fn = data.feature_names
#
# TypeError: ('Expecting data to be a DMatrix object, got: ', <class 'pandas.core.frame.DataFrame'>)

# %%
# xgb_param['objective'] = 'reg:squarederror'  # Hoặc 'reg:absoluteerror'
# model = xgb.XGBRegressor(**xgb_param)

# %%
# eval_set = (val_inputs, val_targets)
# model.fit(train_inputs, train_targets, eval_set=[eval_set], verbose=False)

# %%
# train_preds = model.predict(train_inputs)
# val_preds = model.predict(val_inputs) 
# train_score = np.sqrt(mean_squared_error(train_targets, train_preds))
# val_score = np.sqrt(mean_squared_error(val_targets, val_preds))

# %%
# train_score, val_score

# %%
# test_preds = model.predict(test_inputs)

# %%
# sub_df = pd.DataFrame({
#     'ID': test['ID'],
#     'item_cnt_month': Y_pred.clip(0, 20)
# })
# sub_df.to_csv('submission.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 sub_df = pd.DataFrame({
#       2     'ID': test['ID'],
#       3     'item_cnt_month': Y_pred.clip(0, 20)
#       4 })
#       5 sub_df.to_csv('submission.csv', index=False)
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\construction.py:690, in _extract_index(data)
#     685     if lengths[0] != len(index):
#     686         msg = (
#     687             f"array length {lengths[0]} does not match index "
#     688             f"length {len(index)}"
#     689         )
# --> 690         raise ValueError(msg)
#     691 else:
#     692     index = default_index(lengths[0])
#
# ValueError: array length 238172 does not match index length 214200
